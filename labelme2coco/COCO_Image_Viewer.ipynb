# %% [markdown]
# # COCO Image Viewer
# This notebook will allow you to view details about a COCO dataset and preview segmentations on annotated images.
# Learn more about it at: http://cocodataset.org/

# %%
import IPython
import os
import json
import random
import numpy as np
import requests
from io import BytesIO
from math import trunc
from PIL import Image as PILImage
from PIL import ImageDraw as PILImageDraw

# %%
# Load the dataset json
class CocoDataset():
    def __init__(self, annotation_path, image_dir):
        self.annotation_path = annotation_path
        self.image_dir = image_dir
        self.colors = ['blue', 'purple', 'red', 'green', 'orange', 'salmon', 'pink', 'gold',
                       'orchid', 'slateblue', 'limegreen', 'seagreen', 'darkgreen', 'olive',
                       'teal', 'aquamarine', 'steelblue', 'powderblue', 'dodgerblue', 'navy',
                       'magenta', 'sienna', 'maroon']

        json_file = open(self.annotation_path)
        self.coco = json.load(json_file)
        json_file.close()

        self.process_info()
        self.process_licenses()
        self.process_categories()
        self.process_images()
        self.process_segmentations()

    def display_info(self):
        print('Dataset Info:')
        print('=============')
        if self.info is None:
            return
        for key, item in self.info.items():
            print('  {}: {}'.format(key, item))

        requirements = [['description', str],
                        ['url', str],
                        ['version', str],
                        ['year', int],
                        ['contributor', str],
                        ['date_created', str]]
        for req, req_type in requirements:
            if req not in self.info:
                print('ERROR: {} is missing'.format(req))
            elif type(self.info[req]) != req_type:
                print('ERROR: {} should be type {}'.format(req, str(req_type)))
        print('')

    def display_licenses(self):
        print('Licenses:')
        print('=========')

        if self.licenses is None:
            return
        requirements = [['id', int],
                        ['url', str],
                        ['name', str]]
        for license in self.licenses:
            for key, item in license.items():
                print('  {}: {}'.format(key, item))
            for req, req_type in requirements:
                if req not in license:
                    print('ERROR: {} is missing'.format(req))
                elif type(license[req]) != req_type:
                    print('ERROR: {} should be type {}'.format(
                        req, str(req_type)))
            print('')
        print('')

    def display_categories(self):
        print('Categories:')
        print('=========')
        for sc_key, sc_val in self.super_categories.items():
            print('  super_category: {}'.format(sc_key))
            for cat_id in sc_val:
                print('    id {}: {}'.format(
                    cat_id, self.categories[cat_id]['name']))
            print('')

    def display_image(self, image_id, show_polys=True, show_bbox=True, show_crowds=True, use_url=False):
        print('Image:')
        print('======')
        if image_id == 'random':
            image_id = random.choice(list(self.images.keys()))

        # Print the image info
        image = self.images[image_id]
        for key, val in image.items():
            print('  {}: {}'.format(key, val))

        # Open the image
        if use_url:
            image_path = image['coco_url']
            response = requests.get(image_path)
            image = PILImage.open(BytesIO(response.content))

        else:
            # image_path = os.path.join(self.image_dir, image['file_name'])
            image_path = "{}/{}".format(self.image_dir, image['file_name'])
            image = PILImage.open(image_path)

        # Calculate the size and adjusted display size
        max_width = 600
        image_width, image_height = image.size
        adjusted_width = min(image_width, max_width)
        adjusted_ratio = adjusted_width / image_width
        adjusted_height = adjusted_ratio * image_height

        # Create list of polygons to be drawn
        polygons = {}
        bbox_polygons = {}
        rle_regions = {}
        poly_colors = {}
        bbox_categories = {}
        print('  segmentations ({}):'.format(
            len(self.segmentations[image_id])))
        for i, segm in enumerate(self.segmentations[image_id]):
            polygons_list = []
            if segm['iscrowd'] != 0:
                # Gotta decode the RLE
                px = 0
                x, y = 0, 0
                rle_list = []
                for j, counts in enumerate(segm['segmentation']['counts']):
                    if j % 2 == 0:
                        # Empty pixels
                        px += counts
                    else:
                        # Need to draw on these pixels, since we are drawing in vector form,
                        # we need to draw horizontal lines on the image
                        x_start = trunc(
                            trunc(px / image_height) * adjusted_ratio)
                        y_start = trunc(px % image_height * adjusted_ratio)
                        px += counts
                        x_end = trunc(trunc(px / image_height)
                                      * adjusted_ratio)
                        y_end = trunc(px % image_height * adjusted_ratio)
                        if x_end == x_start:
                            # This is only on one line
                            rle_list.append(
                                {'x': x_start, 'y': y_start, 'width': 1, 'height': (y_end - y_start)})
                        if x_end > x_start:
                            # This spans more than one line
                            # Insert top line first
                            rle_list.append(
                                {'x': x_start, 'y': y_start, 'width': 1, 'height': (image_height - y_start)})

                            # Insert middle lines if needed
                            lines_spanned = x_end - x_start + 1  # total number of lines spanned
                            full_lines_to_insert = lines_spanned - 2
                            if full_lines_to_insert > 0:
                                full_lines_to_insert = trunc(
                                    full_lines_to_insert * adjusted_ratio)
                                rle_list.append(
                                    {'x': (x_start + 1), 'y': 0, 'width': full_lines_to_insert, 'height': image_height})

                            # Insert bottom line
                            rle_list.append(
                                {'x': x_end, 'y': 0, 'width': 1, 'height': y_end})
                if len(rle_list) > 0:
                    rle_regions[segm['id']] = rle_list
            else:
                # Add the polygon segmentation
                for segmentation_points in segm['segmentation']:
                    segmentation_points = np.multiply(
                        segmentation_points, adjusted_ratio).astype(int)
                    polygons_list.append(
                        str(segmentation_points).lstrip('[').rstrip(']'))
            polygons[segm['id']] = polygons_list
            if i < len(self.colors):
                poly_colors[segm['id']] = self.colors[i]
            else:
                poly_colors[segm['id']] = 'white'

            bbox = segm['bbox']
            bbox_points = [bbox[0], bbox[1], bbox[0] + bbox[2], bbox[1],
                           bbox[0] + bbox[2], bbox[1] +
                           bbox[3], bbox[0], bbox[1] + bbox[3],
                           bbox[0], bbox[1]]
            bbox_points = np.multiply(bbox_points, adjusted_ratio).astype(int)
            bbox_polygons[segm['id']] = str(
                bbox_points).lstrip('[').rstrip(']')
            bbox_categories[segm['id']] = self.categories[segm['category_id']]
            # Print details
            print('    {}:{}:{}'.format(
                segm['id'], poly_colors[segm['id']], self.categories[segm['category_id']]))

        # Draw segmentation polygons on image
        html = '<div class="container" style="position:relative;">'
        html += '<img src="{}" style="position:relative;top:0px;left:0px;width:{}px;">'.format(
            image_path, adjusted_width)
        html += '<div class="svgclass"><svg width="{}" height="{}">'.format(
            adjusted_width, adjusted_height)

        if show_polys:
            for seg_id, points_list in polygons.items():
                fill_color = poly_colors[seg_id]
                stroke_color = poly_colors[seg_id]
                for points in points_list:
                    html += '<polygon points="{}" style="fill:{}; stroke:{}; stroke-width:1; fill-opacity:0.5" />'.format(
                        points, fill_color, stroke_color)

        if show_crowds:
            for seg_id, rect_list in rle_regions.items():
                fill_color = poly_colors[seg_id]
                stroke_color = poly_colors[seg_id]
                for rect_def in rect_list:
                    x, y = rect_def['x'], rect_def['y']
                    w, h = rect_def['width'], rect_def['height']
                    html += '<rect x="{}" y="{}" width="{}" height="{}" style="fill:{}; stroke:{}; stroke-width:1; fill-opacity:0.5; stroke-opacity:0.5" />'.format(
                        x, y, w, h, fill_color, stroke_color)

        if show_bbox:
            for seg_id, points in bbox_polygons.items():
                x, y = [int(i) for i in points.split()[:2]]
                html += '<text x="{}" y="{}" fill="yellow">{}</text>'.format(
                    x, y, bbox_categories[seg_id]["name"])
                fill_color = poly_colors[seg_id]
                stroke_color = poly_colors[seg_id]
                html += '<polygon points="{}" style="fill:{}; stroke:{}; stroke-width:1; fill-opacity:0" />'.format(
                    points, fill_color, stroke_color)

        html += '</svg></div>'
        html += '</div>'
        html += '<style>'
        html += '.svgclass { position:absolute; top:0px; left:0px;}'
        html += '</style>'
        return html

    def process_info(self):
        self.info = self.coco.get('info')

    def process_licenses(self):
        self.licenses = self.coco.get('licenses')

    def process_categories(self):
        self.categories = {}
        self.super_categories = {}
        for category in self.coco['categories']:
            cat_id = category['id']
            super_category = category['supercategory']

            # Add category to the categories dict
            if cat_id not in self.categories:
                self.categories[cat_id] = category
            else:
                print("ERROR: Skipping duplicate category id: {}".format(category))

            # Add category to super_categories dict
            if super_category not in self.super_categories:
                # Create a new set with the category id
                self.super_categories[super_category] = {cat_id}
            else:
                self.super_categories[super_category] |= {
                    cat_id}  # Add category id to the set

    def process_images(self):
        self.images = {}
        for image in self.coco['images']:
            image_id = image['id']
            if image_id in self.images:
                print("ERROR: Skipping duplicate image id: {}".format(image))
            else:
                self.images[image_id] = image

    def process_segmentations(self):
        self.segmentations = {}
        for segmentation in self.coco['annotations']:
            image_id = segmentation['image_id']
            if image_id not in self.segmentations:
                self.segmentations[image_id] = []
            self.segmentations[image_id].append(segmentation)

# %%
annotation_path = "train2019.json"
image_dir = "train2019"

coco_dataset = CocoDataset(annotation_path, image_dir)
coco_dataset.display_info()
coco_dataset.display_licenses()
coco_dataset.display_categories()
# Out:
# Dataset Info:
# =============
# Licenses:
# =========
# Categories:
# =========
#   super_category: screw
#     id 0: screw
#
#   super_category: shim
#     id 1: shim

# %%
for k, v in coco_dataset.images.items():
    print(k, v)
# Out:
# 0 {'height': 1080, 'width': 1920, 'id': 0, 'file_name': '823_Color.jpg'}
# 1 {'height': 1080, 'width': 1920, 'id': 1, 'file_name': '518_Color.jpg'}
# 2 {'height': 1080, 'width': 1920, 'id': 2, 'file_name': '755_Color_darker.jpg'}
# 3 {'height': 1080, 'width': 1920, 'id': 3, 'file_name': '474_Color.jpg'}
# 4 {'height': 1080, 'width': 1920, 'id': 4, 'file_name': '548_Color_darker.jpg'}
# 5 {'height': 1080, 'width': 1920, 'id': 5, 'file_name': '693_Color.jpg'}
# 6 {'height': 1080, 'width': 1920, 'id': 6, 'file_name': '600_Color_SaltAndPepper.jpg'}
# 7 {'height': 1080, 'width': 1920, 'id': 7, 'file_name': '621_Color_brighter.jpg'}
# 8 {'height': 1080, 'width': 1920, 'id': 8, 'file_name': '738_Color_darker.jpg'}
# 9 {'height': 1080, 'width': 1920, 'id': 9, 'file_name': '719_Color_SaltAndPepper.jpg'}
# 10 {'height': 1080, 'width': 1920, 'id': 10, 'file_name': '613_Color_addGaussianNoise.jpg'}
# 11 {'height': 1080, 'width': 1920, 'id': 11, 'file_name': '613_Color_SaltAndPepper.jpg'}
# 12 {'height': 1080, 'width': 1920, 'id': 12, 'file_name': '669_Color_brighter.jpg'}
# 13 {'height': 1080, 'width': 1920, 'id': 13, 'file_name': '820_Color.jpg'}
# 14 {'height': 1080, 'width': 1920, 'id': 14, 'file_name': '611_Color_brighter.jpg'}
# 15 {'height': 1080, 'width': 1920, 'id': 15, 'file_name': '664_Color_darker.jpg'}
# 16 {'height': 1080, 'width': 1920, 'id': 16, 'file_name': '688_Color_addGaussianNoise.jpg'}
# 17 {'height': 1080, 'width': 1920, 'id': 17, 'file_name': '666_Color.jpg'}
# 18 {'height': 1080, 'width': 1920, 'id': 18, 'file_name': '730_Color_addGaussianNoise.jpg'}
# 19 {'height': 1080, 'width': 1920, 'id': 19, 'file_name': '821_Color_SaltAndPepper.jpg'}
# 20 {'height': 1080, 'width': 1920, 'id': 20, 'file_name': '542_Color.jpg'}
# 21 {'height': 1080, 'width': 1920, 'id': 21, 'file_name': '727_Color_addGaussianNoise.jpg'}
# 22 {'height': 1080, 'width': 1920, 'id': 22, 'file_name': '602_Color_brighter.jpg'}
# 23 {'height': 1080, 'width': 1920, 'id': 23, 'file_name': '542_Color_addGaussianNoise.jpg'}
# 24 {'height': 1080, 'width': 1920, 'id': 24, 'file_name': '655_Color.jpg'}
# 25 {'height': 1080, 'width': 1920, 'id': 25, 'file_name': '656_Color_brighter.jpg'}
# 26 {'height': 1080, 'width': 1920, 'id': 26, 'file_name': '480_Color_darker.jpg'}
# 27 {'height': 1080, 'width': 1920, 'id': 27, 'file_name': '844_Color_SaltAndPepper.jpg'}
# 28 {'height': 1080, 'width': 1920, 'id': 28, 'file_name': '714_Color_addGaussianNoise.jpg'}
# 29 {'height': 1080, 'width': 1920, 'id': 29, 'file_name': '695_Color_brighter.jpg'}
# 30 {'height': 1080, 'width': 1920, 'id': 30, 'file_name': '726_Color_SaltAndPepper.jpg'}
# 31 {'height': 1080, 'width': 1920, 'id': 31, 'file_name': '816_Color.jpg'}
# 32 {'height': 1080, 'width': 1920, 'id': 32, 'file_name': '660_Color_darker.jpg'}
# 33 {'height': 1080, 'width': 1920, 'id': 33, 'file_name': '546_Color_addGaussianNoise.jpg'}
# 34 {'height': 1080, 'width': 1920, 'id': 34, 'file_name': '529_Color.jpg'}
# 35 {'height': 1080, 'width': 1920, 'id': 35, 'file_name': '553_Color_brighter.jpg'}
# 36 {'height': 1080, 'width': 1920, 'id': 36, 'file_name': '533_Color_SaltAndPepper.jpg'}
# 37 {'height': 1080, 'width': 1920, 'id': 37, 'file_name': '713_Color_addGaussianNoise.jpg'}
# 38 {'height': 1080, 'width': 1920, 'id': 38, 'file_name': '533_Color_addGaussianNoise.jpg'}
# 39 {'height': 1080, 'width': 1920, 'id': 39, 'file_name': '484_Color_brighter.jpg'}
# 40 {'height': 1080, 'width': 1920, 'id': 40, 'file_name': '748_Color_brighter.jpg'}
# 41 {'height': 1080, 'width': 1920, 'id': 41, 'file_name': '687_Color_addGaussianNoise.jpg'}
# 42 {'height': 1080, 'width': 1920, 'id': 42, 'file_name': '531_Color_brighter.jpg'}
# 43 {'height': 1080, 'width': 1920, 'id': 43, 'file_name': '626_Color_addGaussianNoise.jpg'}
# 44 {'height': 1080, 'width': 1920, 'id': 44, 'file_name': '662_Color_darker.jpg'}
# 45 {'height': 1080, 'width': 1920, 'id': 45, 'file_name': '506_Color_addGaussianNoise.jpg'}
# 46 {'height': 1080, 'width': 1920, 'id': 46, 'file_name': '632_Color_darker.jpg'}
# 47 {'height': 1080, 'width': 1920, 'id': 47, 'file_name': '590_Color_darker.jpg'}
# 48 {'height': 1080, 'width': 1920, 'id': 48, 'file_name': '649_Color_SaltAndPepper.jpg'}
# 49 {'height': 1080, 'width': 1920, 'id': 49, 'file_name': '499_Color.jpg'}
# 50 {'height': 1080, 'width': 1920, 'id': 50, 'file_name': '742_Color_brighter.jpg'}
# 51 {'height': 1080, 'width': 1920, 'id': 51, 'file_name': '690_Color.jpg'}
# 52 {'height': 1080, 'width': 1920, 'id': 52, 'file_name': '487_Color.jpg'}
# 53 {'height': 1080, 'width': 1920, 'id': 53, 'file_name': '507_Color.jpg'}
# 54 {'height': 1080, 'width': 1920, 'id': 54, 'file_name': '618_Color.jpg'}
# 55 {'height': 1080, 'width': 1920, 'id': 55, 'file_name': '641_Color.jpg'}
# 56 {'height': 1080, 'width': 1920, 'id': 56, 'file_name': '663_Color.jpg'}
# 57 {'height': 1080, 'width': 1920, 'id': 57, 'file_name': '517_Color_addGaussianNoise.jpg'}
# 58 {'height': 1080, 'width': 1920, 'id': 58, 'file_name': '701_Color_darker.jpg'}
# 59 {'height': 1080, 'width': 1920, 'id': 59, 'file_name': '636_Color.jpg'}
# 60 {'height': 1080, 'width': 1920, 'id': 60, 'file_name': '567_Color_addGaussianNoise.jpg'}
# 61 {'height': 1080, 'width': 1920, 'id': 61, 'file_name': '572_Color_SaltAndPepper.jpg'}
# 62 {'height': 1080, 'width': 1920, 'id': 62, 'file_name': '767_Color_darker.jpg'}
# 63 {'height': 1080, 'width': 1920, 'id': 63, 'file_name': '675_Color_brighter.jpg'}
# 64 {'height': 1080, 'width': 1920, 'id': 64, 'file_name': '538_Color_addGaussianNoise.jpg'}
# 65 {'height': 1080, 'width': 1920, 'id': 65, 'file_name': '840_Color_SaltAndPepper.jpg'}
# 66 {'height': 1080, 'width': 1920, 'id': 66, 'file_name': '753_Color_brighter.jpg'}
# 67 {'height': 1080, 'width': 1920, 'id': 67, 'file_name': '552_Color_darker.jpg'}
# 68 {'height': 1080, 'width': 1920, 'id': 68, 'file_name': '780_Color_brighter.jpg'}
# 69 {'height': 1080, 'width': 1920, 'id': 69, 'file_name': '796_Color_SaltAndPepper.jpg'}
# 70 {'height': 1080, 'width': 1920, 'id': 70, 'file_name': '581_Color_SaltAndPepper.jpg'}
# 71 {'height': 1080, 'width': 1920, 'id': 71, 'file_name': '708_Color.jpg'}
# 72 {'height': 1080, 'width': 1920, 'id': 72, 'file_name': '788_Color_SaltAndPepper.jpg'}
# 73 {'height': 1080, 'width': 1920, 'id': 73, 'file_name': '713_Color.jpg'}
# 74 {'height': 1080, 'width': 1920, 'id': 74, 'file_name': '536_Color.jpg'}
# 75 {'height': 1080, 'width': 1920, 'id': 75, 'file_name': '473_Color_addGaussianNoise.jpg'}
# 76 {'height': 1080, 'width': 1920, 'id': 76, 'file_name': '647_Color_darker.jpg'}
# 77 {'height': 1080, 'width': 1920, 'id': 77, 'file_name': '779_Color_addGaussianNoise.jpg'}
# 78 {'height': 1080, 'width': 1920, 'id': 78, 'file_name': '663_Color_addGaussianNoise.jpg'}
# 79 {'height': 1080, 'width': 1920, 'id': 79, 'file_name': '781_Color_addGaussianNoise.jpg'}
# 80 {'height': 1080, 'width': 1920, 'id': 80, 'file_name': '776_Color_SaltAndPepper.jpg'}
# 81 {'height': 1080, 'width': 1920, 'id': 81, 'file_name': '628_Color_SaltAndPepper.jpg'}
# 82 {'height': 1080, 'width': 1920, 'id': 82, 'file_name': '619_Color_brighter.jpg'}
# 83 {'height': 1080, 'width': 1920, 'id': 83, 'file_name': '455_Color_SaltAndPepper.jpg'}
# 84 {'height': 1080, 'width': 1920, 'id': 84, 'file_name': '741_Color.jpg'}
# 85 {'height': 1080, 'width': 1920, 'id': 85, 'file_name': '466_Color.jpg'}
# 86 {'height': 1080, 'width': 1920, 'id': 86, 'file_name': '603_Color_darker.jpg'}
# 87 {'height': 1080, 'width': 1920, 'id': 87, 'file_name': '575_Color_brighter.jpg'}
# 88 {'height': 1080, 'width': 1920, 'id': 88, 'file_name': '512_Color.jpg'}
# 89 {'height': 1080, 'width': 1920, 'id': 89, 'file_name': '661_Color.jpg'}
# 90 {'height': 1080, 'width': 1920, 'id': 90, 'file_name': '552_Color_brighter.jpg'}
# 91 {'height': 1080, 'width': 1920, 'id': 91, 'file_name': '744_Color.jpg'}
# 92 {'height': 1080, 'width': 1920, 'id': 92, 'file_name': '675_Color_addGaussianNoise.jpg'}
# 93 {'height': 1080, 'width': 1920, 'id': 93, 'file_name': '802_Color_brighter.jpg'}
# 94 {'height': 1080, 'width': 1920, 'id': 94, 'file_name': '571_Color_darker.jpg'}
# 95 {'height': 1080, 'width': 1920, 'id': 95, 'file_name': '759_Color.jpg'}
# 96 {'height': 1080, 'width': 1920, 'id': 96, 'file_name': '734_Color.jpg'}
# 97 {'height': 1080, 'width': 1920, 'id': 97, 'file_name': '705_Color_SaltAndPepper.jpg'}
# 98 {'height': 1080, 'width': 1920, 'id': 98, 'file_name': '522_Color_SaltAndPepper.jpg'}
# 99 {'height': 1080, 'width': 1920, 'id': 99, 'file_name': '592_Color_addGaussianNoise.jpg'}
# 100 {'height': 1080, 'width': 1920, 'id': 100, 'file_name': '801_Color_SaltAndPepper.jpg'}
# 101 {'height': 1080, 'width': 1920, 'id': 101, 'file_name': '793_Color_brighter.jpg'}
# 102 {'height': 1080, 'width': 1920, 'id': 102, 'file_name': '760_Color.jpg'}
# 103 {'height': 1080, 'width': 1920, 'id': 103, 'file_name': '536_Color_addGaussianNoise.jpg'}
# 104 {'height': 1080, 'width': 1920, 'id': 104, 'file_name': '459_Color_brighter.jpg'}
# 105 {'height': 1080, 'width': 1920, 'id': 105, 'file_name': '608_Color_SaltAndPepper.jpg'}
# 106 {'height': 1080, 'width': 1920, 'id': 106, 'file_name': '548_Color_addGaussianNoise.jpg'}
# 107 {'height': 1080, 'width': 1920, 'id': 107, 'file_name': '605_Color_darker.jpg'}
# 108 {'height': 1080, 'width': 1920, 'id': 108, 'file_name': '550_Color_SaltAndPepper.jpg'}
# 109 {'height': 1080, 'width': 1920, 'id': 109, 'file_name': '761_Color_SaltAndPepper.jpg'}
# 110 {'height': 1080, 'width': 1920, 'id': 110, 'file_name': '795_Color_addGaussianNoise.jpg'}
# 111 {'height': 1080, 'width': 1920, 'id': 111, 'file_name': '639_Color_darker.jpg'}
# 112 {'height': 1080, 'width': 1920, 'id': 112, 'file_name': '707_Color_addGaussianNoise.jpg'}
# 113 {'height': 1080, 'width': 1920, 'id': 113, 'file_name': '465_Color_brighter.jpg'}
# 114 {'height': 1080, 'width': 1920, 'id': 114, 'file_name': '466_Color_brighter.jpg'}
# 115 {'height': 1080, 'width': 1920, 'id': 115, 'file_name': '578_Color_darker.jpg'}
# 116 {'height': 1080, 'width': 1920, 'id': 116, 'file_name': '502_Color_SaltAndPepper.jpg'}
# 117 {'height': 1080, 'width': 1920, 'id': 117, 'file_name': '510_Color_addGaussianNoise.jpg'}
# 118 {'height': 1080, 'width': 1920, 'id': 118, 'file_name': '540_Color.jpg'}
# 119 {'height': 1080, 'width': 1920, 'id': 119, 'file_name': '724_Color_SaltAndPepper.jpg'}
# 120 {'height': 1080, 'width': 1920, 'id': 120, 'file_name': '637_Color_darker.jpg'}
# 121 {'height': 1080, 'width': 1920, 'id': 121, 'file_name': '588_Color_addGaussianNoise.jpg'}
# 122 {'height': 1080, 'width': 1920, 'id': 122, 'file_name': '650_Color_SaltAndPepper.jpg'}
# 123 {'height': 1080, 'width': 1920, 'id': 123, 'file_name': '524_Color_brighter.jpg'}
# 124 {'height': 1080, 'width': 1920, 'id': 124, 'file_name': '847_Color_darker.jpg'}
# 125 {'height': 1080, 'width': 1920, 'id': 125, 'file_name': '615_Color_darker.jpg'}
# 126 {'height': 1080, 'width': 1920, 'id': 126, 'file_name': '813_Color.jpg'}
# 127 {'height': 1080, 'width': 1920, 'id': 127, 'file_name': '458_Color_addGaussianNoise.jpg'}
# 128 {'height': 1080, 'width': 1920, 'id': 128, 'file_name': '728_Color.jpg'}
# 129 {'height': 1080, 'width': 1920, 'id': 129, 'file_name': '763_Color.jpg'}
# 130 {'height': 1080, 'width': 1920, 'id': 130, 'file_name': '481_Color_addGaussianNoise.jpg'}
# 131 {'height': 1080, 'width': 1920, 'id': 131, 'file_name': '620_Color_addGaussianNoise.jpg'}
# 132 {'height': 1080, 'width': 1920, 'id': 132, 'file_name': '816_Color_darker.jpg'}
# 133 {'height': 1080, 'width': 1920, 'id': 133, 'file_name': '530_Color_addGaussianNoise.jpg'}
# 134 {'height': 1080, 'width': 1920, 'id': 134, 'file_name': '469_Color_darker.jpg'}
# 135 {'height': 1080, 'width': 1920, 'id': 135, 'file_name': '725_Color_SaltAndPepper.jpg'}
# 136 {'height': 1080, 'width': 1920, 'id': 136, 'file_name': '684_Color_brighter.jpg'}
# 137 {'height': 1080, 'width': 1920, 'id': 137, 'file_name': '586_Color.jpg'}
# 138 {'height': 1080, 'width': 1920, 'id': 138, 'file_name': '782_Color_addGaussianNoise.jpg'}
# 139 {'height': 1080, 'width': 1920, 'id': 139, 'file_name': '572_Color_addGaussianNoise.jpg'}
# 140 {'height': 1080, 'width': 1920, 'id': 140, 'file_name': '627_Color_brighter.jpg'}
# 141 {'height': 1080, 'width': 1920, 'id': 141, 'file_name': '580_Color_addGaussianNoise.jpg'}
# 142 {'height': 1080, 'width': 1920, 'id': 142, 'file_name': '514_Color_SaltAndPepper.jpg'}
# 143 {'height': 1080, 'width': 1920, 'id': 143, 'file_name': '748_Color.jpg'}
# 144 {'height': 1080, 'width': 1920, 'id': 144, 'file_name': '672_Color_addGaussianNoise.jpg'}
# 145 {'height': 1080, 'width': 1920, 'id': 145, 'file_name': '761_Color.jpg'}
# 146 {'height': 1080, 'width': 1920, 'id': 146, 'file_name': '603_Color_SaltAndPepper.jpg'}
# 147 {'height': 1080, 'width': 1920, 'id': 147, 'file_name': '732_Color_brighter.jpg'}
# 148 {'height': 1080, 'width': 1920, 'id': 148, 'file_name': '535_Color_addGaussianNoise.jpg'}
# 149 {'height': 1080, 'width': 1920, 'id': 149, 'file_name': '622_Color_brighter.jpg'}
# 150 {'height': 1080, 'width': 1920, 'id': 150, 'file_name': '470_Color_SaltAndPepper.jpg'}
# 151 {'height': 1080, 'width': 1920, 'id': 151, 'file_name': '567_Color_SaltAndPepper.jpg'}
# 152 {'height': 1080, 'width': 1920, 'id': 152, 'file_name': '709_Color_addGaussianNoise.jpg'}
# 153 {'height': 1080, 'width': 1920, 'id': 153, 'file_name': '489_Color.jpg'}
# 154 {'height': 1080, 'width': 1920, 'id': 154, 'file_name': '663_Color_SaltAndPepper.jpg'}
# 155 {'height': 1080, 'width': 1920, 'id': 155, 'file_name': '703_Color_brighter.jpg'}
# 156 {'height': 1080, 'width': 1920, 'id': 156, 'file_name': '812_Color.jpg'}
# 157 {'height': 1080, 'width': 1920, 'id': 157, 'file_name': '612_Color_addGaussianNoise.jpg'}
# 158 {'height': 1080, 'width': 1920, 'id': 158, 'file_name': '802_Color_darker.jpg'}
# 159 {'height': 1080, 'width': 1920, 'id': 159, 'file_name': '775_Color_darker.jpg'}
# 160 {'height': 1080, 'width': 1920, 'id': 160, 'file_name': '774_Color.jpg'}
# 161 {'height': 1080, 'width': 1920, 'id': 161, 'file_name': '617_Color_darker.jpg'}
# 162 {'height': 1080, 'width': 1920, 'id': 162, 'file_name': '454_Color_darker.jpg'}
# 163 {'height': 1080, 'width': 1920, 'id': 163, 'file_name': '729_Color_SaltAndPepper.jpg'}
# 164 {'height': 1080, 'width': 1920, 'id': 164, 'file_name': '632_Color_brighter.jpg'}
# 165 {'height': 1080, 'width': 1920, 'id': 165, 'file_name': '630_Color_SaltAndPepper.jpg'}
# 166 {'height': 1080, 'width': 1920, 'id': 166, 'file_name': '818_Color_addGaussianNoise.jpg'}
# 167 {'height': 1080, 'width': 1920, 'id': 167, 'file_name': '842_Color_addGaussianNoise.jpg'}
# 168 {'height': 1080, 'width': 1920, 'id': 168, 'file_name': '698_Color_SaltAndPepper.jpg'}
# 169 {'height': 1080, 'width': 1920, 'id': 169, 'file_name': '470_Color_brighter.jpg'}
# 170 {'height': 1080, 'width': 1920, 'id': 170, 'file_name': '456_Color_brighter.jpg'}
# 171 {'height': 1080, 'width': 1920, 'id': 171, 'file_name': '563_Color_brighter.jpg'}
# 172 {'height': 1080, 'width': 1920, 'id': 172, 'file_name': '622_Color_SaltAndPepper.jpg'}
# 173 {'height': 1080, 'width': 1920, 'id': 173, 'file_name': '751_Color_brighter.jpg'}
# 174 {'height': 1080, 'width': 1920, 'id': 174, 'file_name': '690_Color_brighter.jpg'}
# 175 {'height': 1080, 'width': 1920, 'id': 175, 'file_name': '582_Color_darker.jpg'}
# 176 {'height': 1080, 'width': 1920, 'id': 176, 'file_name': '608_Color_darker.jpg'}
# 177 {'height': 1080, 'width': 1920, 'id': 177, 'file_name': '625_Color_addGaussianNoise.jpg'}
# 178 {'height': 1080, 'width': 1920, 'id': 178, 'file_name': '808_Color_darker.jpg'}
# 179 {'height': 1080, 'width': 1920, 'id': 179, 'file_name': '832_Color_SaltAndPepper.jpg'}
# 180 {'height': 1080, 'width': 1920, 'id': 180, 'file_name': '678_Color.jpg'}
# 181 {'height': 1080, 'width': 1920, 'id': 181, 'file_name': '832_Color_addGaussianNoise.jpg'}
# 182 {'height': 1080, 'width': 1920, 'id': 182, 'file_name': '803_Color_darker.jpg'}
# 183 {'height': 1080, 'width': 1920, 'id': 183, 'file_name': '819_Color_addGaussianNoise.jpg'}
# 184 {'height': 1080, 'width': 1920, 'id': 184, 'file_name': '574_Color_SaltAndPepper.jpg'}
# 185 {'height': 1080, 'width': 1920, 'id': 185, 'file_name': '805_Color_brighter.jpg'}
# 186 {'height': 1080, 'width': 1920, 'id': 186, 'file_name': '721_Color.jpg'}
# 187 {'height': 1080, 'width': 1920, 'id': 187, 'file_name': '486_Color_addGaussianNoise.jpg'}
# 188 {'height': 1080, 'width': 1920, 'id': 188, 'file_name': '492_Color_addGaussianNoise.jpg'}
# 189 {'height': 1080, 'width': 1920, 'id': 189, 'file_name': '628_Color_brighter.jpg'}
# 190 {'height': 1080, 'width': 1920, 'id': 190, 'file_name': '468_Color_darker.jpg'}
# 191 {'height': 1080, 'width': 1920, 'id': 191, 'file_name': '526_Color.jpg'}
# 192 {'height': 1080, 'width': 1920, 'id': 192, 'file_name': '451_Color_addGaussianNoise.jpg'}
# 193 {'height': 1080, 'width': 1920, 'id': 193, 'file_name': '775_Color_addGaussianNoise.jpg'}
# 194 {'height': 1080, 'width': 1920, 'id': 194, 'file_name': '634_Color_addGaussianNoise.jpg'}
# 195 {'height': 1080, 'width': 1920, 'id': 195, 'file_name': '700_Color_darker.jpg'}
# 196 {'height': 1080, 'width': 1920, 'id': 196, 'file_name': '817_Color_SaltAndPepper.jpg'}
# 197 {'height': 1080, 'width': 1920, 'id': 197, 'file_name': '735_Color_SaltAndPepper.jpg'}
# 198 {'height': 1080, 'width': 1920, 'id': 198, 'file_name': '789_Color_darker.jpg'}
# 199 {'height': 1080, 'width': 1920, 'id': 199, 'file_name': '573_Color_addGaussianNoise.jpg'}
# 200 {'height': 1080, 'width': 1920, 'id': 200, 'file_name': '824_Color.jpg'}
# 201 {'height': 1080, 'width': 1920, 'id': 201, 'file_name': '786_Color_addGaussianNoise.jpg'}
# 202 {'height': 1080, 'width': 1920, 'id': 202, 'file_name': '535_Color.jpg'}
# 203 {'height': 1080, 'width': 1920, 'id': 203, 'file_name': '606_Color_addGaussianNoise.jpg'}
# 204 {'height': 1080, 'width': 1920, 'id': 204, 'file_name': '581_Color_brighter.jpg'}
# 205 {'height': 1080, 'width': 1920, 'id': 205, 'file_name': '834_Color_darker.jpg'}
# 206 {'height': 1080, 'width': 1920, 'id': 206, 'file_name': '518_Color_brighter.jpg'}
# 207 {'height': 1080, 'width': 1920, 'id': 207, 'file_name': '811_Color_addGaussianNoise.jpg'}
# 208 {'height': 1080, 'width': 1920, 'id': 208, 'file_name': '544_Color_addGaussianNoise.jpg'}
# 209 {'height': 1080, 'width': 1920, 'id': 209, 'file_name': '746_Color_brighter.jpg'}
# 210 {'height': 1080, 'width': 1920, 'id': 210, 'file_name': '745_Color_addGaussianNoise.jpg'}
# 211 {'height': 1080, 'width': 1920, 'id': 211, 'file_name': '675_Color_SaltAndPepper.jpg'}
# 212 {'height': 1080, 'width': 1920, 'id': 212, 'file_name': '539_Color_SaltAndPepper.jpg'}
# 213 {'height': 1080, 'width': 1920, 'id': 213, 'file_name': '757_Color_SaltAndPepper.jpg'}
# 214 {'height': 1080, 'width': 1920, 'id': 214, 'file_name': '797_Color_addGaussianNoise.jpg'}
# 215 {'height': 1080, 'width': 1920, 'id': 215, 'file_name': '462_Color_brighter.jpg'}
# 216 {'height': 1080, 'width': 1920, 'id': 216, 'file_name': '738_Color.jpg'}
# 217 {'height': 1080, 'width': 1920, 'id': 217, 'file_name': '466_Color_addGaussianNoise.jpg'}
# 218 {'height': 1080, 'width': 1920, 'id': 218, 'file_name': '492_Color_darker.jpg'}
# 219 {'height': 1080, 'width': 1920, 'id': 219, 'file_name': '556_Color.jpg'}
# 220 {'height': 1080, 'width': 1920, 'id': 220, 'file_name': '456_Color_addGaussianNoise.jpg'}
# 221 {'height': 1080, 'width': 1920, 'id': 221, 'file_name': '665_Color.jpg'}
# 222 {'height': 1080, 'width': 1920, 'id': 222, 'file_name': '727_Color.jpg'}
# 223 {'height': 1080, 'width': 1920, 'id': 223, 'file_name': '634_Color_brighter.jpg'}
# 224 {'height': 1080, 'width': 1920, 'id': 224, 'file_name': '511_Color_brighter.jpg'}
# 225 {'height': 1080, 'width': 1920, 'id': 225, 'file_name': '773_Color_SaltAndPepper.jpg'}
# 226 {'height': 1080, 'width': 1920, 'id': 226, 'file_name': '787_Color_addGaussianNoise.jpg'}
# 227 {'height': 1080, 'width': 1920, 'id': 227, 'file_name': '767_Color_addGaussianNoise.jpg'}
# 228 {'height': 1080, 'width': 1920, 'id': 228, 'file_name': '695_Color_darker.jpg'}
# 229 {'height': 1080, 'width': 1920, 'id': 229, 'file_name': '614_Color_addGaussianNoise.jpg'}
# 230 {'height': 1080, 'width': 1920, 'id': 230, 'file_name': '800_Color_SaltAndPepper.jpg'}
# 231 {'height': 1080, 'width': 1920, 'id': 231, 'file_name': '833_Color_SaltAndPepper.jpg'}
# 232 {'height': 1080, 'width': 1920, 'id': 232, 'file_name': '487_Color_brighter.jpg'}
# 233 {'height': 1080, 'width': 1920, 'id': 233, 'file_name': '465_Color_addGaussianNoise.jpg'}
# 234 {'height': 1080, 'width': 1920, 'id': 234, 'file_name': '606_Color.jpg'}
# 235 {'height': 1080, 'width': 1920, 'id': 235, 'file_name': '832_Color.jpg'}
# 236 {'height': 1080, 'width': 1920, 'id': 236, 'file_name': '591_Color.jpg'}
# 237 {'height': 1080, 'width': 1920, 'id': 237, 'file_name': '587_Color_darker.jpg'}
# 238 {'height': 1080, 'width': 1920, 'id': 238, 'file_name': '718_Color.jpg'}
# 239 {'height': 1080, 'width': 1920, 'id': 239, 'file_name': '700_Color_SaltAndPepper.jpg'}
# 240 {'height': 1080, 'width': 1920, 'id': 240, 'file_name': '755_Color_SaltAndPepper.jpg'}
# 241 {'height': 1080, 'width': 1920, 'id': 241, 'file_name': '711_Color_SaltAndPepper.jpg'}
# 242 {'height': 1080, 'width': 1920, 'id': 242, 'file_name': '500_Color_addGaussianNoise.jpg'}
# 243 {'height': 1080, 'width': 1920, 'id': 243, 'file_name': '770_Color_darker.jpg'}
# 244 {'height': 1080, 'width': 1920, 'id': 244, 'file_name': '562_Color_addGaussianNoise.jpg'}
# 245 {'height': 1080, 'width': 1920, 'id': 245, 'file_name': '654_Color.jpg'}
# 246 {'height': 1080, 'width': 1920, 'id': 246, 'file_name': '584_Color.jpg'}
# 247 {'height': 1080, 'width': 1920, 'id': 247, 'file_name': '477_Color.jpg'}
# 248 {'height': 1080, 'width': 1920, 'id': 248, 'file_name': '549_Color.jpg'}
# 249 {'height': 1080, 'width': 1920, 'id': 249, 'file_name': '792_Color_addGaussianNoise.jpg'}
# 250 {'height': 1080, 'width': 1920, 'id': 250, 'file_name': '800_Color.jpg'}
# 251 {'height': 1080, 'width': 1920, 'id': 251, 'file_name': '710_Color_addGaussianNoise.jpg'}
# 252 {'height': 1080, 'width': 1920, 'id': 252, 'file_name': '756_Color_SaltAndPepper.jpg'}
# 253 {'height': 1080, 'width': 1920, 'id': 253, 'file_name': '816_Color_SaltAndPepper.jpg'}
# 254 {'height': 1080, 'width': 1920, 'id': 254, 'file_name': '601_Color.jpg'}
# 255 {'height': 1080, 'width': 1920, 'id': 255, 'file_name': '748_Color_darker.jpg'}
# 256 {'height': 1080, 'width': 1920, 'id': 256, 'file_name': '826_Color_addGaussianNoise.jpg'}
# 257 {'height': 1080, 'width': 1920, 'id': 257, 'file_name': '694_Color.jpg'}
# 258 {'height': 1080, 'width': 1920, 'id': 258, 'file_name': '681_Color_addGaussianNoise.jpg'}
# 259 {'height': 1080, 'width': 1920, 'id': 259, 'file_name': '741_Color_SaltAndPepper.jpg'}
# 260 {'height': 1080, 'width': 1920, 'id': 260, 'file_name': '595_Color_darker.jpg'}
# 261 {'height': 1080, 'width': 1920, 'id': 261, 'file_name': '845_Color_brighter.jpg'}
# 262 {'height': 1080, 'width': 1920, 'id': 262, 'file_name': '850_Color_addGaussianNoise.jpg'}
# 263 {'height': 1080, 'width': 1920, 'id': 263, 'file_name': '613_Color.jpg'}
# 264 {'height': 1080, 'width': 1920, 'id': 264, 'file_name': '487_Color_SaltAndPepper.jpg'}
# 265 {'height': 1080, 'width': 1920, 'id': 265, 'file_name': '834_Color_addGaussianNoise.jpg'}
# 266 {'height': 1080, 'width': 1920, 'id': 266, 'file_name': '521_Color_darker.jpg'}
# 267 {'height': 1080, 'width': 1920, 'id': 267, 'file_name': '790_Color.jpg'}
# 268 {'height': 1080, 'width': 1920, 'id': 268, 'file_name': '654_Color_darker.jpg'}
# 269 {'height': 1080, 'width': 1920, 'id': 269, 'file_name': '647_Color_brighter.jpg'}
# 270 {'height': 1080, 'width': 1920, 'id': 270, 'file_name': '556_Color_brighter.jpg'}
# 271 {'height': 1080, 'width': 1920, 'id': 271, 'file_name': '608_Color_addGaussianNoise.jpg'}
# 272 {'height': 1080, 'width': 1920, 'id': 272, 'file_name': '580_Color_brighter.jpg'}
# 273 {'height': 1080, 'width': 1920, 'id': 273, 'file_name': '706_Color_darker.jpg'}
# 274 {'height': 1080, 'width': 1920, 'id': 274, 'file_name': '503_Color.jpg'}
# 275 {'height': 1080, 'width': 1920, 'id': 275, 'file_name': '818_Color_SaltAndPepper.jpg'}
# 276 {'height': 1080, 'width': 1920, 'id': 276, 'file_name': '526_Color_brighter.jpg'}
# 277 {'height': 1080, 'width': 1920, 'id': 277, 'file_name': '850_Color_darker.jpg'}
# 278 {'height': 1080, 'width': 1920, 'id': 278, 'file_name': '634_Color_darker.jpg'}
# 279 {'height': 1080, 'width': 1920, 'id': 279, 'file_name': '574_Color_addGaussianNoise.jpg'}
# 280 {'height': 1080, 'width': 1920, 'id': 280, 'file_name': '628_Color_darker.jpg'}
# 281 {'height': 1080, 'width': 1920, 'id': 281, 'file_name': '578_Color.jpg'}
# 282 {'height': 1080, 'width': 1920, 'id': 282, 'file_name': '500_Color_brighter.jpg'}
# 283 {'height': 1080, 'width': 1920, 'id': 283, 'file_name': '529_Color_brighter.jpg'}
# 284 {'height': 1080, 'width': 1920, 'id': 284, 'file_name': '670_Color_brighter.jpg'}
# 285 {'height': 1080, 'width': 1920, 'id': 285, 'file_name': '700_Color_brighter.jpg'}
# 286 {'height': 1080, 'width': 1920, 'id': 286, 'file_name': '518_Color_SaltAndPepper.jpg'}
# 287 {'height': 1080, 'width': 1920, 'id': 287, 'file_name': '502_Color.jpg'}
# 288 {'height': 1080, 'width': 1920, 'id': 288, 'file_name': '780_Color.jpg'}
# 289 {'height': 1080, 'width': 1920, 'id': 289, 'file_name': '629_Color_brighter.jpg'}
# 290 {'height': 1080, 'width': 1920, 'id': 290, 'file_name': '554_Color_brighter.jpg'}
# 291 {'height': 1080, 'width': 1920, 'id': 291, 'file_name': '761_Color_darker.jpg'}
# 292 {'height': 1080, 'width': 1920, 'id': 292, 'file_name': '829_Color_SaltAndPepper.jpg'}
# 293 {'height': 1080, 'width': 1920, 'id': 293, 'file_name': '550_Color.jpg'}
# 294 {'height': 1080, 'width': 1920, 'id': 294, 'file_name': '813_Color_brighter.jpg'}
# 295 {'height': 1080, 'width': 1920, 'id': 295, 'file_name': '729_Color_addGaussianNoise.jpg'}
# 296 {'height': 1080, 'width': 1920, 'id': 296, 'file_name': '804_Color.jpg'}
# 297 {'height': 1080, 'width': 1920, 'id': 297, 'file_name': '493_Color.jpg'}
# 298 {'height': 1080, 'width': 1920, 'id': 298, 'file_name': '598_Color_SaltAndPepper.jpg'}
# 299 {'height': 1080, 'width': 1920, 'id': 299, 'file_name': '716_Color_darker.jpg'}
# 300 {'height': 1080, 'width': 1920, 'id': 300, 'file_name': '510_Color_darker.jpg'}
# 301 {'height': 1080, 'width': 1920, 'id': 301, 'file_name': '570_Color_brighter.jpg'}
# 302 {'height': 1080, 'width': 1920, 'id': 302, 'file_name': '835_Color_darker.jpg'}
# 303 {'height': 1080, 'width': 1920, 'id': 303, 'file_name': '458_Color.jpg'}
# 304 {'height': 1080, 'width': 1920, 'id': 304, 'file_name': '631_Color_SaltAndPepper.jpg'}
# 305 {'height': 1080, 'width': 1920, 'id': 305, 'file_name': '582_Color.jpg'}
# 306 {'height': 1080, 'width': 1920, 'id': 306, 'file_name': '727_Color_darker.jpg'}
# 307 {'height': 1080, 'width': 1920, 'id': 307, 'file_name': '530_Color.jpg'}
# 308 {'height': 1080, 'width': 1920, 'id': 308, 'file_name': '530_Color_brighter.jpg'}
# 309 {'height': 1080, 'width': 1920, 'id': 309, 'file_name': '680_Color.jpg'}
# 310 {'height': 1080, 'width': 1920, 'id': 310, 'file_name': '797_Color.jpg'}
# 311 {'height': 1080, 'width': 1920, 'id': 311, 'file_name': '494_Color_SaltAndPepper.jpg'}
# 312 {'height': 1080, 'width': 1920, 'id': 312, 'file_name': '666_Color_brighter.jpg'}
# 313 {'height': 1080, 'width': 1920, 'id': 313, 'file_name': '473_Color_brighter.jpg'}
# 314 {'height': 1080, 'width': 1920, 'id': 314, 'file_name': '524_Color.jpg'}
# 315 {'height': 1080, 'width': 1920, 'id': 315, 'file_name': '599_Color_addGaussianNoise.jpg'}
# 316 {'height': 1080, 'width': 1920, 'id': 316, 'file_name': '666_Color_addGaussianNoise.jpg'}
# 317 {'height': 1080, 'width': 1920, 'id': 317, 'file_name': '692_Color_brighter.jpg'}
# 318 {'height': 1080, 'width': 1920, 'id': 318, 'file_name': '777_Color_addGaussianNoise.jpg'}
# 319 {'height': 1080, 'width': 1920, 'id': 319, 'file_name': '734_Color_darker.jpg'}
# 320 {'height': 1080, 'width': 1920, 'id': 320, 'file_name': '520_Color_darker.jpg'}
# 321 {'height': 1080, 'width': 1920, 'id': 321, 'file_name': '510_Color_SaltAndPepper.jpg'}
# 322 {'height': 1080, 'width': 1920, 'id': 322, 'file_name': '544_Color.jpg'}
# 323 {'height': 1080, 'width': 1920, 'id': 323, 'file_name': '615_Color.jpg'}
# 324 {'height': 1080, 'width': 1920, 'id': 324, 'file_name': '486_Color_brighter.jpg'}
# 325 {'height': 1080, 'width': 1920, 'id': 325, 'file_name': '725_Color_darker.jpg'}
# 326 {'height': 1080, 'width': 1920, 'id': 326, 'file_name': '693_Color_brighter.jpg'}
# 327 {'height': 1080, 'width': 1920, 'id': 327, 'file_name': '532_Color_darker.jpg'}
# 328 {'height': 1080, 'width': 1920, 'id': 328, 'file_name': '452_Color_darker.jpg'}
# 329 {'height': 1080, 'width': 1920, 'id': 329, 'file_name': '560_Color_SaltAndPepper.jpg'}
# 330 {'height': 1080, 'width': 1920, 'id': 330, 'file_name': '642_Color_darker.jpg'}
# 331 {'height': 1080, 'width': 1920, 'id': 331, 'file_name': '572_Color.jpg'}
# 332 {'height': 1080, 'width': 1920, 'id': 332, 'file_name': '815_Color_darker.jpg'}
# 333 {'height': 1080, 'width': 1920, 'id': 333, 'file_name': '737_Color.jpg'}
# 334 {'height': 1080, 'width': 1920, 'id': 334, 'file_name': '627_Color_addGaussianNoise.jpg'}
# 335 {'height': 1080, 'width': 1920, 'id': 335, 'file_name': '620_Color_darker.jpg'}
# 336 {'height': 1080, 'width': 1920, 'id': 336, 'file_name': '473_Color.jpg'}
# 337 {'height': 1080, 'width': 1920, 'id': 337, 'file_name': '562_Color_SaltAndPepper.jpg'}
# 338 {'height': 1080, 'width': 1920, 'id': 338, 'file_name': '517_Color_SaltAndPepper.jpg'}
# 339 {'height': 1080, 'width': 1920, 'id': 339, 'file_name': '832_Color_brighter.jpg'}
# 340 {'height': 1080, 'width': 1920, 'id': 340, 'file_name': '474_Color_SaltAndPepper.jpg'}
# 341 {'height': 1080, 'width': 1920, 'id': 341, 'file_name': '732_Color_addGaussianNoise.jpg'}
# 342 {'height': 1080, 'width': 1920, 'id': 342, 'file_name': '510_Color.jpg'}
# 343 {'height': 1080, 'width': 1920, 'id': 343, 'file_name': '719_Color_darker.jpg'}
# 344 {'height': 1080, 'width': 1920, 'id': 344, 'file_name': '462_Color_darker.jpg'}
# 345 {'height': 1080, 'width': 1920, 'id': 345, 'file_name': '657_Color_SaltAndPepper.jpg'}
# 346 {'height': 1080, 'width': 1920, 'id': 346, 'file_name': '559_Color.jpg'}
# 347 {'height': 1080, 'width': 1920, 'id': 347, 'file_name': '521_Color_SaltAndPepper.jpg'}
# 348 {'height': 1080, 'width': 1920, 'id': 348, 'file_name': '545_Color_SaltAndPepper.jpg'}
# 349 {'height': 1080, 'width': 1920, 'id': 349, 'file_name': '523_Color_SaltAndPepper.jpg'}
# 350 {'height': 1080, 'width': 1920, 'id': 350, 'file_name': '720_Color_darker.jpg'}
# 351 {'height': 1080, 'width': 1920, 'id': 351, 'file_name': '579_Color_addGaussianNoise.jpg'}
# 352 {'height': 1080, 'width': 1920, 'id': 352, 'file_name': '798_Color_brighter.jpg'}
# 353 {'height': 1080, 'width': 1920, 'id': 353, 'file_name': '681_Color_darker.jpg'}
# 354 {'height': 1080, 'width': 1920, 'id': 354, 'file_name': '548_Color.jpg'}
# 355 {'height': 1080, 'width': 1920, 'id': 355, 'file_name': '569_Color.jpg'}
# 356 {'height': 1080, 'width': 1920, 'id': 356, 'file_name': '520_Color_addGaussianNoise.jpg'}
# 357 {'height': 1080, 'width': 1920, 'id': 357, 'file_name': '848_Color_addGaussianNoise.jpg'}
# 358 {'height': 1080, 'width': 1920, 'id': 358, 'file_name': '535_Color_SaltAndPepper.jpg'}
# 359 {'height': 1080, 'width': 1920, 'id': 359, 'file_name': '532_Color_addGaussianNoise.jpg'}
# 360 {'height': 1080, 'width': 1920, 'id': 360, 'file_name': '464_Color_addGaussianNoise.jpg'}
# 361 {'height': 1080, 'width': 1920, 'id': 361, 'file_name': '771_Color_darker.jpg'}
# 362 {'height': 1080, 'width': 1920, 'id': 362, 'file_name': '607_Color_brighter.jpg'}
# 363 {'height': 1080, 'width': 1920, 'id': 363, 'file_name': '581_Color_addGaussianNoise.jpg'}
# 364 {'height': 1080, 'width': 1920, 'id': 364, 'file_name': '577_Color_brighter.jpg'}
# 365 {'height': 1080, 'width': 1920, 'id': 365, 'file_name': '589_Color_SaltAndPepper.jpg'}
# 366 {'height': 1080, 'width': 1920, 'id': 366, 'file_name': '670_Color_addGaussianNoise.jpg'}
# 367 {'height': 1080, 'width': 1920, 'id': 367, 'file_name': '515_Color_brighter.jpg'}
# 368 {'height': 1080, 'width': 1920, 'id': 368, 'file_name': '735_Color_darker.jpg'}
# 369 {'height': 1080, 'width': 1920, 'id': 369, 'file_name': '805_Color.jpg'}
# 370 {'height': 1080, 'width': 1920, 'id': 370, 'file_name': '648_Color_addGaussianNoise.jpg'}
# 371 {'height': 1080, 'width': 1920, 'id': 371, 'file_name': '469_Color_addGaussianNoise.jpg'}
# 372 {'height': 1080, 'width': 1920, 'id': 372, 'file_name': '767_Color_SaltAndPepper.jpg'}
# 373 {'height': 1080, 'width': 1920, 'id': 373, 'file_name': '659_Color_brighter.jpg'}
# 374 {'height': 1080, 'width': 1920, 'id': 374, 'file_name': '609_Color_SaltAndPepper.jpg'}
# 375 {'height': 1080, 'width': 1920, 'id': 375, 'file_name': '607_Color.jpg'}
# 376 {'height': 1080, 'width': 1920, 'id': 376, 'file_name': '664_Color_addGaussianNoise.jpg'}
# 377 {'height': 1080, 'width': 1920, 'id': 377, 'file_name': '546_Color_brighter.jpg'}
# 378 {'height': 1080, 'width': 1920, 'id': 378, 'file_name': '731_Color_darker.jpg'}
# 379 {'height': 1080, 'width': 1920, 'id': 379, 'file_name': '648_Color_SaltAndPepper.jpg'}
# 380 {'height': 1080, 'width': 1920, 'id': 380, 'file_name': '794_Color.jpg'}
# 381 {'height': 1080, 'width': 1920, 'id': 381, 'file_name': '711_Color.jpg'}
# 382 {'height': 1080, 'width': 1920, 'id': 382, 'file_name': '837_Color_darker.jpg'}
# 383 {'height': 1080, 'width': 1920, 'id': 383, 'file_name': '496_Color_darker.jpg'}
# 384 {'height': 1080, 'width': 1920, 'id': 384, 'file_name': '555_Color_addGaussianNoise.jpg'}
# 385 {'height': 1080, 'width': 1920, 'id': 385, 'file_name': '604_Color_SaltAndPepper.jpg'}
# 386 {'height': 1080, 'width': 1920, 'id': 386, 'file_name': '659_Color_darker.jpg'}
# 387 {'height': 1080, 'width': 1920, 'id': 387, 'file_name': '814_Color_brighter.jpg'}
# 388 {'height': 1080, 'width': 1920, 'id': 388, 'file_name': '598_Color_darker.jpg'}
# 389 {'height': 1080, 'width': 1920, 'id': 389, 'file_name': '539_Color.jpg'}
# 390 {'height': 1080, 'width': 1920, 'id': 390, 'file_name': '516_Color.jpg'}
# 391 {'height': 1080, 'width': 1920, 'id': 391, 'file_name': '627_Color_darker.jpg'}
# 392 {'height': 1080, 'width': 1920, 'id': 392, 'file_name': '587_Color_SaltAndPepper.jpg'}
# 393 {'height': 1080, 'width': 1920, 'id': 393, 'file_name': '747_Color_brighter.jpg'}
# 394 {'height': 1080, 'width': 1920, 'id': 394, 'file_name': '746_Color_darker.jpg'}
# 395 {'height': 1080, 'width': 1920, 'id': 395, 'file_name': '743_Color_SaltAndPepper.jpg'}
# 396 {'height': 1080, 'width': 1920, 'id': 396, 'file_name': '473_Color_darker.jpg'}
# 397 {'height': 1080, 'width': 1920, 'id': 397, 'file_name': '783_Color.jpg'}
# 398 {'height': 1080, 'width': 1920, 'id': 398, 'file_name': '460_Color_brighter.jpg'}
# 399 {'height': 1080, 'width': 1920, 'id': 399, 'file_name': '771_Color_brighter.jpg'}
# 400 {'height': 1080, 'width': 1920, 'id': 400, 'file_name': '546_Color.jpg'}
# 401 {'height': 1080, 'width': 1920, 'id': 401, 'file_name': '666_Color_SaltAndPepper.jpg'}
# 402 {'height': 1080, 'width': 1920, 'id': 402, 'file_name': '588_Color_darker.jpg'}
# 403 {'height': 1080, 'width': 1920, 'id': 403, 'file_name': '548_Color_SaltAndPepper.jpg'}
# 404 {'height': 1080, 'width': 1920, 'id': 404, 'file_name': '500_Color_SaltAndPepper.jpg'}
# 405 {'height': 1080, 'width': 1920, 'id': 405, 'file_name': '676_Color_addGaussianNoise.jpg'}
# 406 {'height': 1080, 'width': 1920, 'id': 406, 'file_name': '764_Color.jpg'}
# 407 {'height': 1080, 'width': 1920, 'id': 407, 'file_name': '648_Color_brighter.jpg'}
# 408 {'height': 1080, 'width': 1920, 'id': 408, 'file_name': '826_Color.jpg'}
# 409 {'height': 1080, 'width': 1920, 'id': 409, 'file_name': '549_Color_brighter.jpg'}
# 410 {'height': 1080, 'width': 1920, 'id': 410, 'file_name': '660_Color_brighter.jpg'}
# 411 {'height': 1080, 'width': 1920, 'id': 411, 'file_name': '619_Color.jpg'}
# 412 {'height': 1080, 'width': 1920, 'id': 412, 'file_name': '531_Color_SaltAndPepper.jpg'}
# 413 {'height': 1080, 'width': 1920, 'id': 413, 'file_name': '773_Color.jpg'}
# 414 {'height': 1080, 'width': 1920, 'id': 414, 'file_name': '719_Color_brighter.jpg'}
# 415 {'height': 1080, 'width': 1920, 'id': 415, 'file_name': '748_Color_addGaussianNoise.jpg'}
# 416 {'height': 1080, 'width': 1920, 'id': 416, 'file_name': '485_Color.jpg'}
# 417 {'height': 1080, 'width': 1920, 'id': 417, 'file_name': '737_Color_addGaussianNoise.jpg'}
# 418 {'height': 1080, 'width': 1920, 'id': 418, 'file_name': '609_Color_brighter.jpg'}
# 419 {'height': 1080, 'width': 1920, 'id': 419, 'file_name': '799_Color_SaltAndPepper.jpg'}
# 420 {'height': 1080, 'width': 1920, 'id': 420, 'file_name': '747_Color_SaltAndPepper.jpg'}
# 421 {'height': 1080, 'width': 1920, 'id': 421, 'file_name': '632_Color.jpg'}
# 422 {'height': 1080, 'width': 1920, 'id': 422, 'file_name': '555_Color_brighter.jpg'}
# 423 {'height': 1080, 'width': 1920, 'id': 423, 'file_name': '790_Color_addGaussianNoise.jpg'}
# 424 {'height': 1080, 'width': 1920, 'id': 424, 'file_name': '522_Color_darker.jpg'}
# 425 {'height': 1080, 'width': 1920, 'id': 425, 'file_name': '720_Color.jpg'}
# 426 {'height': 1080, 'width': 1920, 'id': 426, 'file_name': '683_Color.jpg'}
# 427 {'height': 1080, 'width': 1920, 'id': 427, 'file_name': '689_Color_brighter.jpg'}
# 428 {'height': 1080, 'width': 1920, 'id': 428, 'file_name': '534_Color_brighter.jpg'}
# 429 {'height': 1080, 'width': 1920, 'id': 429, 'file_name': '844_Color.jpg'}
# 430 {'height': 1080, 'width': 1920, 'id': 430, 'file_name': '452_Color_brighter.jpg'}
# 431 {'height': 1080, 'width': 1920, 'id': 431, 'file_name': '809_Color_SaltAndPepper.jpg'}
# 432 {'height': 1080, 'width': 1920, 'id': 432, 'file_name': '744_Color_SaltAndPepper.jpg'}
# 433 {'height': 1080, 'width': 1920, 'id': 433, 'file_name': '556_Color_darker.jpg'}
# 434 {'height': 1080, 'width': 1920, 'id': 434, 'file_name': '611_Color_darker.jpg'}
# 435 {'height': 1080, 'width': 1920, 'id': 435, 'file_name': '615_Color_SaltAndPepper.jpg'}
# 436 {'height': 1080, 'width': 1920, 'id': 436, 'file_name': '698_Color.jpg'}
# 437 {'height': 1080, 'width': 1920, 'id': 437, 'file_name': '526_Color_SaltAndPepper.jpg'}
# 438 {'height': 1080, 'width': 1920, 'id': 438, 'file_name': '496_Color_brighter.jpg'}
# 439 {'height': 1080, 'width': 1920, 'id': 439, 'file_name': '676_Color.jpg'}
# 440 {'height': 1080, 'width': 1920, 'id': 440, 'file_name': '715_Color.jpg'}
# 441 {'height': 1080, 'width': 1920, 'id': 441, 'file_name': '453_Color_addGaussianNoise.jpg'}
# 442 {'height': 1080, 'width': 1920, 'id': 442, 'file_name': '780_Color_darker.jpg'}
# 443 {'height': 1080, 'width': 1920, 'id': 443, 'file_name': '844_Color_brighter.jpg'}
# 444 {'height': 1080, 'width': 1920, 'id': 444, 'file_name': '836_Color.jpg'}
# 445 {'height': 1080, 'width': 1920, 'id': 445, 'file_name': '730_Color_brighter.jpg'}
# 446 {'height': 1080, 'width': 1920, 'id': 446, 'file_name': '515_Color_addGaussianNoise.jpg'}
# 447 {'height': 1080, 'width': 1920, 'id': 447, 'file_name': '505_Color_SaltAndPepper.jpg'}
# 448 {'height': 1080, 'width': 1920, 'id': 448, 'file_name': '617_Color_SaltAndPepper.jpg'}
# 449 {'height': 1080, 'width': 1920, 'id': 449, 'file_name': '739_Color_addGaussianNoise.jpg'}
# 450 {'height': 1080, 'width': 1920, 'id': 450, 'file_name': '827_Color_addGaussianNoise.jpg'}
# 451 {'height': 1080, 'width': 1920, 'id': 451, 'file_name': '736_Color_darker.jpg'}
# 452 {'height': 1080, 'width': 1920, 'id': 452, 'file_name': '752_Color_brighter.jpg'}
# 453 {'height': 1080, 'width': 1920, 'id': 453, 'file_name': '540_Color_SaltAndPepper.jpg'}
# 454 {'height': 1080, 'width': 1920, 'id': 454, 'file_name': '617_Color.jpg'}
# 455 {'height': 1080, 'width': 1920, 'id': 455, 'file_name': '835_Color_addGaussianNoise.jpg'}
# 456 {'height': 1080, 'width': 1920, 'id': 456, 'file_name': '754_Color_addGaussianNoise.jpg'}
# 457 {'height': 1080, 'width': 1920, 'id': 457, 'file_name': '815_Color_addGaussianNoise.jpg'}
# 458 {'height': 1080, 'width': 1920, 'id': 458, 'file_name': '785_Color_SaltAndPepper.jpg'}
# 459 {'height': 1080, 'width': 1920, 'id': 459, 'file_name': '520_Color_brighter.jpg'}
# 460 {'height': 1080, 'width': 1920, 'id': 460, 'file_name': '796_Color_brighter.jpg'}
# 461 {'height': 1080, 'width': 1920, 'id': 461, 'file_name': '712_Color_addGaussianNoise.jpg'}
# 462 {'height': 1080, 'width': 1920, 'id': 462, 'file_name': '819_Color_SaltAndPepper.jpg'}
# 463 {'height': 1080, 'width': 1920, 'id': 463, 'file_name': '471_Color_darker.jpg'}
# 464 {'height': 1080, 'width': 1920, 'id': 464, 'file_name': '842_Color.jpg'}
# 465 {'height': 1080, 'width': 1920, 'id': 465, 'file_name': '667_Color.jpg'}
# 466 {'height': 1080, 'width': 1920, 'id': 466, 'file_name': '504_Color_brighter.jpg'}
# 467 {'height': 1080, 'width': 1920, 'id': 467, 'file_name': '590_Color_addGaussianNoise.jpg'}
# 468 {'height': 1080, 'width': 1920, 'id': 468, 'file_name': '534_Color_addGaussianNoise.jpg'}
# 469 {'height': 1080, 'width': 1920, 'id': 469, 'file_name': '746_Color_addGaussianNoise.jpg'}
# 470 {'height': 1080, 'width': 1920, 'id': 470, 'file_name': '559_Color_darker.jpg'}
# 471 {'height': 1080, 'width': 1920, 'id': 471, 'file_name': '760_Color_darker.jpg'}
# 472 {'height': 1080, 'width': 1920, 'id': 472, 'file_name': '504_Color_darker.jpg'}
# 473 {'height': 1080, 'width': 1920, 'id': 473, 'file_name': '785_Color.jpg'}
# 474 {'height': 1080, 'width': 1920, 'id': 474, 'file_name': '574_Color.jpg'}
# 475 {'height': 1080, 'width': 1920, 'id': 475, 'file_name': '740_Color_addGaussianNoise.jpg'}
# 476 {'height': 1080, 'width': 1920, 'id': 476, 'file_name': '615_Color_brighter.jpg'}
# 477 {'height': 1080, 'width': 1920, 'id': 477, 'file_name': '844_Color_addGaussianNoise.jpg'}
# 478 {'height': 1080, 'width': 1920, 'id': 478, 'file_name': '802_Color_addGaussianNoise.jpg'}
# 479 {'height': 1080, 'width': 1920, 'id': 479, 'file_name': '608_Color.jpg'}
# 480 {'height': 1080, 'width': 1920, 'id': 480, 'file_name': '723_Color.jpg'}
# 481 {'height': 1080, 'width': 1920, 'id': 481, 'file_name': '723_Color_darker.jpg'}
# 482 {'height': 1080, 'width': 1920, 'id': 482, 'file_name': '793_Color_darker.jpg'}
# 483 {'height': 1080, 'width': 1920, 'id': 483, 'file_name': '692_Color.jpg'}
# 484 {'height': 1080, 'width': 1920, 'id': 484, 'file_name': '490_Color_darker.jpg'}
# 485 {'height': 1080, 'width': 1920, 'id': 485, 'file_name': '724_Color.jpg'}
# 486 {'height': 1080, 'width': 1920, 'id': 486, 'file_name': '725_Color.jpg'}
# 487 {'height': 1080, 'width': 1920, 'id': 487, 'file_name': '564_Color_addGaussianNoise.jpg'}
# 488 {'height': 1080, 'width': 1920, 'id': 488, 'file_name': '829_Color_darker.jpg'}
# 489 {'height': 1080, 'width': 1920, 'id': 489, 'file_name': '777_Color_brighter.jpg'}
# 490 {'height': 1080, 'width': 1920, 'id': 490, 'file_name': '770_Color.jpg'}
# 491 {'height': 1080, 'width': 1920, 'id': 491, 'file_name': '660_Color_SaltAndPepper.jpg'}
# 492 {'height': 1080, 'width': 1920, 'id': 492, 'file_name': '697_Color.jpg'}
# 493 {'height': 1080, 'width': 1920, 'id': 493, 'file_name': '653_Color.jpg'}
# 494 {'height': 1080, 'width': 1920, 'id': 494, 'file_name': '773_Color_addGaussianNoise.jpg'}
# 495 {'height': 1080, 'width': 1920, 'id': 495, 'file_name': '587_Color_brighter.jpg'}
# 496 {'height': 1080, 'width': 1920, 'id': 496, 'file_name': '672_Color_darker.jpg'}
# 497 {'height': 1080, 'width': 1920, 'id': 497, 'file_name': '560_Color_addGaussianNoise.jpg'}
# 498 {'height': 1080, 'width': 1920, 'id': 498, 'file_name': '794_Color_darker.jpg'}
# 499 {'height': 1080, 'width': 1920, 'id': 499, 'file_name': '457_Color_SaltAndPepper.jpg'}
# 500 {'height': 1080, 'width': 1920, 'id': 500, 'file_name': '533_Color_brighter.jpg'}
# 501 {'height': 1080, 'width': 1920, 'id': 501, 'file_name': '755_Color_addGaussianNoise.jpg'}
# 502 {'height': 1080, 'width': 1920, 'id': 502, 'file_name': '765_Color.jpg'}
# 503 {'height': 1080, 'width': 1920, 'id': 503, 'file_name': '738_Color_brighter.jpg'}
# 504 {'height': 1080, 'width': 1920, 'id': 504, 'file_name': '758_Color_SaltAndPepper.jpg'}
# 505 {'height': 1080, 'width': 1920, 'id': 505, 'file_name': '702_Color.jpg'}
# 506 {'height': 1080, 'width': 1920, 'id': 506, 'file_name': '513_Color_SaltAndPepper.jpg'}
# 507 {'height': 1080, 'width': 1920, 'id': 507, 'file_name': '595_Color_brighter.jpg'}
# 508 {'height': 1080, 'width': 1920, 'id': 508, 'file_name': '734_Color_brighter.jpg'}
# 509 {'height': 1080, 'width': 1920, 'id': 509, 'file_name': '572_Color_darker.jpg'}
# 510 {'height': 1080, 'width': 1920, 'id': 510, 'file_name': '470_Color_darker.jpg'}
# 511 {'height': 1080, 'width': 1920, 'id': 511, 'file_name': '750_Color_brighter.jpg'}
# 512 {'height': 1080, 'width': 1920, 'id': 512, 'file_name': '791_Color_brighter.jpg'}
# 513 {'height': 1080, 'width': 1920, 'id': 513, 'file_name': '549_Color_addGaussianNoise.jpg'}
# 514 {'height': 1080, 'width': 1920, 'id': 514, 'file_name': '599_Color_SaltAndPepper.jpg'}
# 515 {'height': 1080, 'width': 1920, 'id': 515, 'file_name': '530_Color_SaltAndPepper.jpg'}
# 516 {'height': 1080, 'width': 1920, 'id': 516, 'file_name': '651_Color_darker.jpg'}
# 517 {'height': 1080, 'width': 1920, 'id': 517, 'file_name': '830_Color_brighter.jpg'}
# 518 {'height': 1080, 'width': 1920, 'id': 518, 'file_name': '491_Color_brighter.jpg'}
# 519 {'height': 1080, 'width': 1920, 'id': 519, 'file_name': '674_Color.jpg'}
# 520 {'height': 1080, 'width': 1920, 'id': 520, 'file_name': '550_Color_brighter.jpg'}
# 521 {'height': 1080, 'width': 1920, 'id': 521, 'file_name': '822_Color_darker.jpg'}
# 522 {'height': 1080, 'width': 1920, 'id': 522, 'file_name': '691_Color_brighter.jpg'}
# 523 {'height': 1080, 'width': 1920, 'id': 523, 'file_name': '762_Color_SaltAndPepper.jpg'}
# 524 {'height': 1080, 'width': 1920, 'id': 524, 'file_name': '662_Color_addGaussianNoise.jpg'}
# 525 {'height': 1080, 'width': 1920, 'id': 525, 'file_name': '499_Color_darker.jpg'}
# 526 {'height': 1080, 'width': 1920, 'id': 526, 'file_name': '829_Color_brighter.jpg'}
# 527 {'height': 1080, 'width': 1920, 'id': 527, 'file_name': '483_Color_addGaussianNoise.jpg'}
# 528 {'height': 1080, 'width': 1920, 'id': 528, 'file_name': '468_Color_brighter.jpg'}
# 529 {'height': 1080, 'width': 1920, 'id': 529, 'file_name': '642_Color_SaltAndPepper.jpg'}
# 530 {'height': 1080, 'width': 1920, 'id': 530, 'file_name': '564_Color_SaltAndPepper.jpg'}
# 531 {'height': 1080, 'width': 1920, 'id': 531, 'file_name': '647_Color_SaltAndPepper.jpg'}
# 532 {'height': 1080, 'width': 1920, 'id': 532, 'file_name': '849_Color.jpg'}
# 533 {'height': 1080, 'width': 1920, 'id': 533, 'file_name': '745_Color_darker.jpg'}
# 534 {'height': 1080, 'width': 1920, 'id': 534, 'file_name': '491_Color_SaltAndPepper.jpg'}
# 535 {'height': 1080, 'width': 1920, 'id': 535, 'file_name': '585_Color_darker.jpg'}
# 536 {'height': 1080, 'width': 1920, 'id': 536, 'file_name': '508_Color_addGaussianNoise.jpg'}
# 537 {'height': 1080, 'width': 1920, 'id': 537, 'file_name': '720_Color_brighter.jpg'}
# 538 {'height': 1080, 'width': 1920, 'id': 538, 'file_name': '846_Color_addGaussianNoise.jpg'}
# 539 {'height': 1080, 'width': 1920, 'id': 539, 'file_name': '488_Color_SaltAndPepper.jpg'}
# 540 {'height': 1080, 'width': 1920, 'id': 540, 'file_name': '631_Color_addGaussianNoise.jpg'}
# 541 {'height': 1080, 'width': 1920, 'id': 541, 'file_name': '825_Color_addGaussianNoise.jpg'}
# 542 {'height': 1080, 'width': 1920, 'id': 542, 'file_name': '558_Color_addGaussianNoise.jpg'}
# 543 {'height': 1080, 'width': 1920, 'id': 543, 'file_name': '546_Color_darker.jpg'}
# 544 {'height': 1080, 'width': 1920, 'id': 544, 'file_name': '567_Color_brighter.jpg'}
# 545 {'height': 1080, 'width': 1920, 'id': 545, 'file_name': '644_Color.jpg'}
# 546 {'height': 1080, 'width': 1920, 'id': 546, 'file_name': '622_Color.jpg'}
# 547 {'height': 1080, 'width': 1920, 'id': 547, 'file_name': '566_Color_SaltAndPepper.jpg'}
# 548 {'height': 1080, 'width': 1920, 'id': 548, 'file_name': '562_Color_darker.jpg'}
# 549 {'height': 1080, 'width': 1920, 'id': 549, 'file_name': '600_Color_darker.jpg'}
# 550 {'height': 1080, 'width': 1920, 'id': 550, 'file_name': '534_Color.jpg'}
# 551 {'height': 1080, 'width': 1920, 'id': 551, 'file_name': '582_Color_SaltAndPepper.jpg'}
# 552 {'height': 1080, 'width': 1920, 'id': 552, 'file_name': '736_Color_SaltAndPepper.jpg'}
# 553 {'height': 1080, 'width': 1920, 'id': 553, 'file_name': '785_Color_addGaussianNoise.jpg'}
# 554 {'height': 1080, 'width': 1920, 'id': 554, 'file_name': '529_Color_SaltAndPepper.jpg'}
# 555 {'height': 1080, 'width': 1920, 'id': 555, 'file_name': '653_Color_SaltAndPepper.jpg'}
# 556 {'height': 1080, 'width': 1920, 'id': 556, 'file_name': '620_Color_SaltAndPepper.jpg'}
# 557 {'height': 1080, 'width': 1920, 'id': 557, 'file_name': '702_Color_darker.jpg'}
# ...
# 1220 {'height': 1080, 'width': 1920, 'id': 1220, 'file_name': '635_Color_addGaussianNoise.jpg'}
# 1221 {'height': 1080, 'width': 1920, 'id': 1221, 'file_name': '503_Color_darker.jpg'}
# 1222 {'height': 1080, 'width': 1920, 'id': 1222, 'file_name': '741_Color_addGaussianNoise.jpg'}
# 1223 {'height': 1080, 'width': 1920, 'id': 1223, 'file_name': '788_Color_addGaussianNoise.jpg'}
# 1224 {'height': 1080, 'width': 1920, 'id': 1224, 'file_name': '524_Color_addGaussianNoise.jpg'}
# 1225 {'height': 1080, 'width': 1920, 'id': 1225, 'file_name': '559_Color_SaltAndPepper.jpg'}
# 1226 {'height': 1080, 'width': 1920, 'id': 1226, 'file_name': '788_Color_darker.jpg'}
# 1227 {'height': 1080, 'width': 1920, 'id': 1227, 'file_name': '693_Color_addGaussianNoise.jpg'}
# 1228 {'height': 1080, 'width': 1920, 'id': 1228, 'file_name': '620_Color.jpg'}
# 1229 {'height': 1080, 'width': 1920, 'id': 1229, 'file_name': '657_Color_brighter.jpg'}
# 1230 {'height': 1080, 'width': 1920, 'id': 1230, 'file_name': '707_Color_SaltAndPepper.jpg'}
# 1231 {'height': 1080, 'width': 1920, 'id': 1231, 'file_name': '777_Color_darker.jpg'}
# 1232 {'height': 1080, 'width': 1920, 'id': 1232, 'file_name': '726_Color_darker.jpg'}
# 1233 {'height': 1080, 'width': 1920, 'id': 1233, 'file_name': '551_Color_darker.jpg'}
# 1234 {'height': 1080, 'width': 1920, 'id': 1234, 'file_name': '758_Color_addGaussianNoise.jpg'}
# 1235 {'height': 1080, 'width': 1920, 'id': 1235, 'file_name': '477_Color_darker.jpg'}
# 1236 {'height': 1080, 'width': 1920, 'id': 1236, 'file_name': '594_Color_darker.jpg'}
# 1237 {'height': 1080, 'width': 1920, 'id': 1237, 'file_name': '741_Color_brighter.jpg'}
# 1238 {'height': 1080, 'width': 1920, 'id': 1238, 'file_name': '451_Color.jpg'}
# 1239 {'height': 1080, 'width': 1920, 'id': 1239, 'file_name': '669_Color_SaltAndPepper.jpg'}
# 1240 {'height': 1080, 'width': 1920, 'id': 1240, 'file_name': '755_Color_brighter.jpg'}
# 1241 {'height': 1080, 'width': 1920, 'id': 1241, 'file_name': '523_Color_darker.jpg'}
# 1242 {'height': 1080, 'width': 1920, 'id': 1242, 'file_name': '779_Color_brighter.jpg'}
# 1243 {'height': 1080, 'width': 1920, 'id': 1243, 'file_name': '476_Color_addGaussianNoise.jpg'}
# 1244 {'height': 1080, 'width': 1920, 'id': 1244, 'file_name': '783_Color_brighter.jpg'}
# 1245 {'height': 1080, 'width': 1920, 'id': 1245, 'file_name': '556_Color_SaltAndPepper.jpg'}
# 1246 {'height': 1080, 'width': 1920, 'id': 1246, 'file_name': '457_Color_brighter.jpg'}
# 1247 {'height': 1080, 'width': 1920, 'id': 1247, 'file_name': '506_Color.jpg'}
# 1248 {'height': 1080, 'width': 1920, 'id': 1248, 'file_name': '537_Color.jpg'}
# 1249 {'height': 1080, 'width': 1920, 'id': 1249, 'file_name': '630_Color_darker.jpg'}
# 1250 {'height': 1080, 'width': 1920, 'id': 1250, 'file_name': '605_Color_addGaussianNoise.jpg'}
# 1251 {'height': 1080, 'width': 1920, 'id': 1251, 'file_name': '649_Color.jpg'}
# 1252 {'height': 1080, 'width': 1920, 'id': 1252, 'file_name': '639_Color_addGaussianNoise.jpg'}
# 1253 {'height': 1080, 'width': 1920, 'id': 1253, 'file_name': '458_Color_SaltAndPepper.jpg'}
# 1254 {'height': 1080, 'width': 1920, 'id': 1254, 'file_name': '753_Color_addGaussianNoise.jpg'}
# 1255 {'height': 1080, 'width': 1920, 'id': 1255, 'file_name': '565_Color_darker.jpg'}
# 1256 {'height': 1080, 'width': 1920, 'id': 1256, 'file_name': '583_Color_addGaussianNoise.jpg'}
# 1257 {'height': 1080, 'width': 1920, 'id': 1257, 'file_name': '522_Color_addGaussianNoise.jpg'}
# 1258 {'height': 1080, 'width': 1920, 'id': 1258, 'file_name': '609_Color.jpg'}
# 1259 {'height': 1080, 'width': 1920, 'id': 1259, 'file_name': '615_Color_addGaussianNoise.jpg'}
# 1260 {'height': 1080, 'width': 1920, 'id': 1260, 'file_name': '739_Color_darker.jpg'}
# 1261 {'height': 1080, 'width': 1920, 'id': 1261, 'file_name': '492_Color_SaltAndPepper.jpg'}
# 1262 {'height': 1080, 'width': 1920, 'id': 1262, 'file_name': '679_Color_SaltAndPepper.jpg'}
# 1263 {'height': 1080, 'width': 1920, 'id': 1263, 'file_name': '751_Color_darker.jpg'}
# 1264 {'height': 1080, 'width': 1920, 'id': 1264, 'file_name': '583_Color_SaltAndPepper.jpg'}
# 1265 {'height': 1080, 'width': 1920, 'id': 1265, 'file_name': '464_Color_darker.jpg'}
# 1266 {'height': 1080, 'width': 1920, 'id': 1266, 'file_name': '730_Color_darker.jpg'}
# 1267 {'height': 1080, 'width': 1920, 'id': 1267, 'file_name': '537_Color_SaltAndPepper.jpg'}
# 1268 {'height': 1080, 'width': 1920, 'id': 1268, 'file_name': '843_Color_darker.jpg'}
# 1269 {'height': 1080, 'width': 1920, 'id': 1269, 'file_name': '757_Color_brighter.jpg'}
# 1270 {'height': 1080, 'width': 1920, 'id': 1270, 'file_name': '659_Color_addGaussianNoise.jpg'}
# 1271 {'height': 1080, 'width': 1920, 'id': 1271, 'file_name': '668_Color_darker.jpg'}
# 1272 {'height': 1080, 'width': 1920, 'id': 1272, 'file_name': '593_Color_brighter.jpg'}
# 1273 {'height': 1080, 'width': 1920, 'id': 1273, 'file_name': '472_Color_darker.jpg'}
# 1274 {'height': 1080, 'width': 1920, 'id': 1274, 'file_name': '758_Color_darker.jpg'}
# 1275 {'height': 1080, 'width': 1920, 'id': 1275, 'file_name': '597_Color.jpg'}
# 1276 {'height': 1080, 'width': 1920, 'id': 1276, 'file_name': '807_Color_darker.jpg'}
# 1277 {'height': 1080, 'width': 1920, 'id': 1277, 'file_name': '637_Color_addGaussianNoise.jpg'}
# 1278 {'height': 1080, 'width': 1920, 'id': 1278, 'file_name': '798_Color_darker.jpg'}
# 1279 {'height': 1080, 'width': 1920, 'id': 1279, 'file_name': '583_Color_darker.jpg'}
# 1280 {'height': 1080, 'width': 1920, 'id': 1280, 'file_name': '778_Color_brighter.jpg'}
# 1281 {'height': 1080, 'width': 1920, 'id': 1281, 'file_name': '459_Color_addGaussianNoise.jpg'}
# 1282 {'height': 1080, 'width': 1920, 'id': 1282, 'file_name': '698_Color_addGaussianNoise.jpg'}
# 1283 {'height': 1080, 'width': 1920, 'id': 1283, 'file_name': '601_Color_brighter.jpg'}
# 1284 {'height': 1080, 'width': 1920, 'id': 1284, 'file_name': '624_Color_brighter.jpg'}
# 1285 {'height': 1080, 'width': 1920, 'id': 1285, 'file_name': '527_Color_SaltAndPepper.jpg'}
# 1286 {'height': 1080, 'width': 1920, 'id': 1286, 'file_name': '643_Color_addGaussianNoise.jpg'}
# 1287 {'height': 1080, 'width': 1920, 'id': 1287, 'file_name': '710_Color_brighter.jpg'}
# 1288 {'height': 1080, 'width': 1920, 'id': 1288, 'file_name': '785_Color_brighter.jpg'}
# 1289 {'height': 1080, 'width': 1920, 'id': 1289, 'file_name': '650_Color_brighter.jpg'}
# 1290 {'height': 1080, 'width': 1920, 'id': 1290, 'file_name': '589_Color.jpg'}
# 1291 {'height': 1080, 'width': 1920, 'id': 1291, 'file_name': '506_Color_brighter.jpg'}
# 1292 {'height': 1080, 'width': 1920, 'id': 1292, 'file_name': '648_Color_darker.jpg'}
# 1293 {'height': 1080, 'width': 1920, 'id': 1293, 'file_name': '644_Color_brighter.jpg'}
# 1294 {'height': 1080, 'width': 1920, 'id': 1294, 'file_name': '563_Color_addGaussianNoise.jpg'}
# 1295 {'height': 1080, 'width': 1920, 'id': 1295, 'file_name': '735_Color_addGaussianNoise.jpg'}
# 1296 {'height': 1080, 'width': 1920, 'id': 1296, 'file_name': '846_Color_SaltAndPepper.jpg'}
# 1297 {'height': 1080, 'width': 1920, 'id': 1297, 'file_name': '769_Color_SaltAndPepper.jpg'}
# 1298 {'height': 1080, 'width': 1920, 'id': 1298, 'file_name': '498_Color_addGaussianNoise.jpg'}
# 1299 {'height': 1080, 'width': 1920, 'id': 1299, 'file_name': '463_Color_SaltAndPepper.jpg'}
# 1300 {'height': 1080, 'width': 1920, 'id': 1300, 'file_name': '838_Color_SaltAndPepper.jpg'}
# 1301 {'height': 1080, 'width': 1920, 'id': 1301, 'file_name': '813_Color_SaltAndPepper.jpg'}
# 1302 {'height': 1080, 'width': 1920, 'id': 1302, 'file_name': '508_Color_brighter.jpg'}
# 1303 {'height': 1080, 'width': 1920, 'id': 1303, 'file_name': '777_Color.jpg'}
# 1304 {'height': 1080, 'width': 1920, 'id': 1304, 'file_name': '754_Color_darker.jpg'}
# 1305 {'height': 1080, 'width': 1920, 'id': 1305, 'file_name': '576_Color.jpg'}
# 1306 {'height': 1080, 'width': 1920, 'id': 1306, 'file_name': '699_Color.jpg'}
# 1307 {'height': 1080, 'width': 1920, 'id': 1307, 'file_name': '712_Color_brighter.jpg'}
# 1308 {'height': 1080, 'width': 1920, 'id': 1308, 'file_name': '482_Color_brighter.jpg'}
# 1309 {'height': 1080, 'width': 1920, 'id': 1309, 'file_name': '782_Color_SaltAndPepper.jpg'}
# 1310 {'height': 1080, 'width': 1920, 'id': 1310, 'file_name': '674_Color_brighter.jpg'}
# 1311 {'height': 1080, 'width': 1920, 'id': 1311, 'file_name': '831_Color.jpg'}
# 1312 {'height': 1080, 'width': 1920, 'id': 1312, 'file_name': '776_Color_brighter.jpg'}
# 1313 {'height': 1080, 'width': 1920, 'id': 1313, 'file_name': '595_Color.jpg'}
# 1314 {'height': 1080, 'width': 1920, 'id': 1314, 'file_name': '718_Color_SaltAndPepper.jpg'}
# 1315 {'height': 1080, 'width': 1920, 'id': 1315, 'file_name': '574_Color_darker.jpg'}
# 1316 {'height': 1080, 'width': 1920, 'id': 1316, 'file_name': '461_Color_addGaussianNoise.jpg'}
# 1317 {'height': 1080, 'width': 1920, 'id': 1317, 'file_name': '747_Color.jpg'}
# 1318 {'height': 1080, 'width': 1920, 'id': 1318, 'file_name': '606_Color_darker.jpg'}
# 1319 {'height': 1080, 'width': 1920, 'id': 1319, 'file_name': '674_Color_SaltAndPepper.jpg'}
# 1320 {'height': 1080, 'width': 1920, 'id': 1320, 'file_name': '721_Color_brighter.jpg'}
# 1321 {'height': 1080, 'width': 1920, 'id': 1321, 'file_name': '556_Color_addGaussianNoise.jpg'}
# 1322 {'height': 1080, 'width': 1920, 'id': 1322, 'file_name': '795_Color_SaltAndPepper.jpg'}
# 1323 {'height': 1080, 'width': 1920, 'id': 1323, 'file_name': '462_Color_addGaussianNoise.jpg'}
# 1324 {'height': 1080, 'width': 1920, 'id': 1324, 'file_name': '593_Color_SaltAndPepper.jpg'}
# 1325 {'height': 1080, 'width': 1920, 'id': 1325, 'file_name': '486_Color.jpg'}
# 1326 {'height': 1080, 'width': 1920, 'id': 1326, 'file_name': '814_Color.jpg'}
# 1327 {'height': 1080, 'width': 1920, 'id': 1327, 'file_name': '828_Color_addGaussianNoise.jpg'}
# 1328 {'height': 1080, 'width': 1920, 'id': 1328, 'file_name': '798_Color.jpg'}
# 1329 {'height': 1080, 'width': 1920, 'id': 1329, 'file_name': '789_Color_SaltAndPepper.jpg'}
# 1330 {'height': 1080, 'width': 1920, 'id': 1330, 'file_name': '580_Color_darker.jpg'}
# 1331 {'height': 1080, 'width': 1920, 'id': 1331, 'file_name': '647_Color_addGaussianNoise.jpg'}
# 1332 {'height': 1080, 'width': 1920, 'id': 1332, 'file_name': '614_Color_SaltAndPepper.jpg'}
# 1333 {'height': 1080, 'width': 1920, 'id': 1333, 'file_name': '744_Color_addGaussianNoise.jpg'}
# 1334 {'height': 1080, 'width': 1920, 'id': 1334, 'file_name': '816_Color_brighter.jpg'}
# 1335 {'height': 1080, 'width': 1920, 'id': 1335, 'file_name': '762_Color_darker.jpg'}
# 1336 {'height': 1080, 'width': 1920, 'id': 1336, 'file_name': '589_Color_brighter.jpg'}
# 1337 {'height': 1080, 'width': 1920, 'id': 1337, 'file_name': '701_Color.jpg'}
# 1338 {'height': 1080, 'width': 1920, 'id': 1338, 'file_name': '451_Color_darker.jpg'}
# 1339 {'height': 1080, 'width': 1920, 'id': 1339, 'file_name': '575_Color_SaltAndPepper.jpg'}
# 1340 {'height': 1080, 'width': 1920, 'id': 1340, 'file_name': '569_Color_darker.jpg'}
# 1341 {'height': 1080, 'width': 1920, 'id': 1341, 'file_name': '808_Color_SaltAndPepper.jpg'}
# 1342 {'height': 1080, 'width': 1920, 'id': 1342, 'file_name': '707_Color_darker.jpg'}
# 1343 {'height': 1080, 'width': 1920, 'id': 1343, 'file_name': '761_Color_addGaussianNoise.jpg'}
# 1344 {'height': 1080, 'width': 1920, 'id': 1344, 'file_name': '745_Color_SaltAndPepper.jpg'}
# 1345 {'height': 1080, 'width': 1920, 'id': 1345, 'file_name': '706_Color_brighter.jpg'}
# 1346 {'height': 1080, 'width': 1920, 'id': 1346, 'file_name': '672_Color_brighter.jpg'}
# 1347 {'height': 1080, 'width': 1920, 'id': 1347, 'file_name': '696_Color_SaltAndPepper.jpg'}
# 1348 {'height': 1080, 'width': 1920, 'id': 1348, 'file_name': '822_Color_brighter.jpg'}
# 1349 {'height': 1080, 'width': 1920, 'id': 1349, 'file_name': '497_Color.jpg'}
# 1350 {'height': 1080, 'width': 1920, 'id': 1350, 'file_name': '694_Color_SaltAndPepper.jpg'}
# 1351 {'height': 1080, 'width': 1920, 'id': 1351, 'file_name': '756_Color_addGaussianNoise.jpg'}
# 1352 {'height': 1080, 'width': 1920, 'id': 1352, 'file_name': '589_Color_darker.jpg'}
# 1353 {'height': 1080, 'width': 1920, 'id': 1353, 'file_name': '549_Color_SaltAndPepper.jpg'}
# 1354 {'height': 1080, 'width': 1920, 'id': 1354, 'file_name': '846_Color_brighter.jpg'}
# 1355 {'height': 1080, 'width': 1920, 'id': 1355, 'file_name': '742_Color_SaltAndPepper.jpg'}
# 1356 {'height': 1080, 'width': 1920, 'id': 1356, 'file_name': '794_Color_addGaussianNoise.jpg'}
# 1357 {'height': 1080, 'width': 1920, 'id': 1357, 'file_name': '506_Color_SaltAndPepper.jpg'}
# 1358 {'height': 1080, 'width': 1920, 'id': 1358, 'file_name': '637_Color.jpg'}
# 1359 {'height': 1080, 'width': 1920, 'id': 1359, 'file_name': '598_Color.jpg'}
# 1360 {'height': 1080, 'width': 1920, 'id': 1360, 'file_name': '547_Color.jpg'}
# 1361 {'height': 1080, 'width': 1920, 'id': 1361, 'file_name': '769_Color.jpg'}
# 1362 {'height': 1080, 'width': 1920, 'id': 1362, 'file_name': '587_Color.jpg'}
# 1363 {'height': 1080, 'width': 1920, 'id': 1363, 'file_name': '818_Color.jpg'}
# 1364 {'height': 1080, 'width': 1920, 'id': 1364, 'file_name': '705_Color_brighter.jpg'}
# 1365 {'height': 1080, 'width': 1920, 'id': 1365, 'file_name': '559_Color_brighter.jpg'}
# 1366 {'height': 1080, 'width': 1920, 'id': 1366, 'file_name': '813_Color_addGaussianNoise.jpg'}
# 1367 {'height': 1080, 'width': 1920, 'id': 1367, 'file_name': '776_Color_addGaussianNoise.jpg'}
# 1368 {'height': 1080, 'width': 1920, 'id': 1368, 'file_name': '557_Color_addGaussianNoise.jpg'}
# 1369 {'height': 1080, 'width': 1920, 'id': 1369, 'file_name': '839_Color.jpg'}
# 1370 {'height': 1080, 'width': 1920, 'id': 1370, 'file_name': '658_Color.jpg'}
# 1371 {'height': 1080, 'width': 1920, 'id': 1371, 'file_name': '594_Color_SaltAndPepper.jpg'}
# 1372 {'height': 1080, 'width': 1920, 'id': 1372, 'file_name': '712_Color.jpg'}
# 1373 {'height': 1080, 'width': 1920, 'id': 1373, 'file_name': '517_Color.jpg'}
# 1374 {'height': 1080, 'width': 1920, 'id': 1374, 'file_name': '484_Color_SaltAndPepper.jpg'}
# 1375 {'height': 1080, 'width': 1920, 'id': 1375, 'file_name': '610_Color_darker.jpg'}
# 1376 {'height': 1080, 'width': 1920, 'id': 1376, 'file_name': '841_Color_darker.jpg'}
# 1377 {'height': 1080, 'width': 1920, 'id': 1377, 'file_name': '821_Color_darker.jpg'}
# 1378 {'height': 1080, 'width': 1920, 'id': 1378, 'file_name': '687_Color_darker.jpg'}
# 1379 {'height': 1080, 'width': 1920, 'id': 1379, 'file_name': '658_Color_addGaussianNoise.jpg'}
# 1380 {'height': 1080, 'width': 1920, 'id': 1380, 'file_name': '731_Color_SaltAndPepper.jpg'}
# 1381 {'height': 1080, 'width': 1920, 'id': 1381, 'file_name': '618_Color_SaltAndPepper.jpg'}
# 1382 {'height': 1080, 'width': 1920, 'id': 1382, 'file_name': '479_Color_SaltAndPepper.jpg'}
# 1383 {'height': 1080, 'width': 1920, 'id': 1383, 'file_name': '596_Color_darker.jpg'}
# 1384 {'height': 1080, 'width': 1920, 'id': 1384, 'file_name': '525_Color_addGaussianNoise.jpg'}
# 1385 {'height': 1080, 'width': 1920, 'id': 1385, 'file_name': '496_Color.jpg'}
# 1386 {'height': 1080, 'width': 1920, 'id': 1386, 'file_name': '683_Color_addGaussianNoise.jpg'}
# 1387 {'height': 1080, 'width': 1920, 'id': 1387, 'file_name': '817_Color_brighter.jpg'}
# 1388 {'height': 1080, 'width': 1920, 'id': 1388, 'file_name': '489_Color_addGaussianNoise.jpg'}
# 1389 {'height': 1080, 'width': 1920, 'id': 1389, 'file_name': '571_Color_addGaussianNoise.jpg'}
# 1390 {'height': 1080, 'width': 1920, 'id': 1390, 'file_name': '820_Color_brighter.jpg'}
# 1391 {'height': 1080, 'width': 1920, 'id': 1391, 'file_name': '729_Color_darker.jpg'}
# 1392 {'height': 1080, 'width': 1920, 'id': 1392, 'file_name': '628_Color_addGaussianNoise.jpg'}
# 1393 {'height': 1080, 'width': 1920, 'id': 1393, 'file_name': '586_Color_brighter.jpg'}
# 1394 {'height': 1080, 'width': 1920, 'id': 1394, 'file_name': '828_Color_SaltAndPepper.jpg'}
# 1395 {'height': 1080, 'width': 1920, 'id': 1395, 'file_name': '607_Color_darker.jpg'}
# 1396 {'height': 1080, 'width': 1920, 'id': 1396, 'file_name': '481_Color_SaltAndPepper.jpg'}
# 1397 {'height': 1080, 'width': 1920, 'id': 1397, 'file_name': '662_Color_SaltAndPepper.jpg'}
# 1398 {'height': 1080, 'width': 1920, 'id': 1398, 'file_name': '781_Color_SaltAndPepper.jpg'}
# 1399 {'height': 1080, 'width': 1920, 'id': 1399, 'file_name': '456_Color_darker.jpg'}

# %%
html = coco_dataset.display_image(5, use_url=False)
IPython.display.HTML(html)
# Out:
# Image:
# ======
#   height: 1080
#   width: 1920
#   id: 5
#   file_name: 693_Color.jpg
#   segmentations (21):
#     119:blue:{'supercategory': 'screw', 'id': 0, 'name': 'screw'}
#     120:purple:{'supercategory': 'screw', 'id': 0, 'name': 'screw'}
#     121:red:{'supercategory': 'screw', 'id': 0, 'name': 'screw'}
#     122:green:{'supercategory': 'screw', 'id': 0, 'name': 'screw'}
#     123:orange:{'supercategory': 'screw', 'id': 0, 'name': 'screw'}
#     124:salmon:{'supercategory': 'screw', 'id': 0, 'name': 'screw'}
#     125:pink:{'supercategory': 'screw', 'id': 0, 'name': 'screw'}
#     126:gold:{'supercategory': 'screw', 'id': 0, 'name': 'screw'}
#     127:orchid:{'supercategory': 'screw', 'id': 0, 'name': 'screw'}
#     128:slateblue:{'supercategory': 'screw', 'id': 0, 'name': 'screw'}
#     129:limegreen:{'supercategory': 'screw', 'id': 0, 'name': 'screw'}
#     130:seagreen:{'supercategory': 'screw', 'id': 0, 'name': 'screw'}
#     131:darkgreen:{'supercategory': 'shim', 'id': 1, 'name': 'shim'}
#     132:olive:{'supercategory': 'shim', 'id': 1, 'name': 'shim'}
#     133:teal:{'supercategory': 'shim', 'id': 1, 'name': 'shim'}
#     134:aquamarine:{'supercategory': 'shim', 'id': 1, 'name': 'shim'}
#     135:steelblue:{'supercategory': 'shim', 'id': 1, 'name': 'shim'}
#     136:powderblue:{'supercategory': 'shim', 'id': 1, 'name': 'shim'}
#     137:dodgerblue:{'supercategory': 'shim', 'id': 1, 'name': 'shim'}
#     138:navy:{'supercategory': 'shim', 'id': 1, 'name': 'shim'}
#     139:magenta:{'supercategory': 'shim', 'id': 1, 'name': 'shim'}
# <div class="container" style="position:relative;"><img src="train2019/693_Color.jpg" style="position:relative;top:0px;left:0px;width:600px;"><div class="svgclass"><svg width="600" height="337.5"><polygon points="203 185 202 186 201 189 203 191 205 190 207 190 211 191 212 190 213 189
#  212 188 207 187 206 187 205 186" style="fill:blue; stroke:blue; stroke-width:1; fill-opacity:0.5" /><polygon points="209 192 208 192 206 194 207 197 209 197 212 196 212 195 216 191 216 189
#  216 188 215 188 214 188 213 189 212 190 211 191 210 192" style="fill:purple; stroke:purple; stroke-width:1; fill-opacity:0.5" /><polygon points="231 207 228 210 229 215 231 215 235 219 236 220 237 221 239 220 240 219
#  240 216 238 213 239 212 237 208 234 207 232 207" style="fill:red; stroke:red; stroke-width:1; fill-opacity:0.5" /><polygon points="237 183 240 183 240 184 241 186 256 185 257 186 257 187 256 189 256 190
#  241 190 241 191 241 192 239 192 238 192 237 190 237 185" style="fill:green; stroke:green; stroke-width:1; fill-opacity:0.5" /><polygon points="233 176 232 177 233 179 235 179 236 177 235 176" style="fill:orange; stroke:orange; stroke-width:1; fill-opacity:0.5" /><polygon points="267 208 267 209 268 210 269 210 280 205 281 206 282 205 283 205 282 202
#  282 201 280 201 279 201 279 202 279 203 268 207" style="fill:salmon; stroke:salmon; stroke-width:1; fill-opacity:0.5" /><polygon points="304 193 303 193 301 194 301 195 302 197 303 198 306 197 306 196 310 194
#  311 193 310 192 309 191 309 191" style="fill:pink; stroke:pink; stroke-width:1; fill-opacity:0.5" /><polygon points="287 185 286 185 285 187 286 188 287 189 289 189 290 187 290 187 295 184
#  295 182 294 181 293 181 292 181 288 185" style="fill:gold; stroke:gold; stroke-width:1; fill-opacity:0.5" /><polygon points="334 226 331 230 332 233 336 237 340 235 341 234 357 229 357 228 357 226
#  357 224 356 224 339 227 337 225 334 226" style="fill:orchid; stroke:orchid; stroke-width:1; fill-opacity:0.5" /><polygon points="340 191 335 198 332 199 332 205 333 207 336 208 340 206 341 202 341 201
#  346 194 346 192 345 191 344 190 342 190 341 190" style="fill:slateblue; stroke:slateblue; stroke-width:1; fill-opacity:0.5" /><polygon points="356 183 354 182 353 183 352 184 353 187 354 189 353 191 354 193 356 194
#  358 194 360 193 362 192 363 191 360 186 358 186 356 183" style="fill:limegreen; stroke:limegreen; stroke-width:1; fill-opacity:0.5" /><polygon points="387 197 386 198 386 199 379 204 379 205 380 206 381 206 388 201 389 201
#  390 200 390 197" style="fill:seagreen; stroke:seagreen; stroke-width:1; fill-opacity:0.5" /><polygon points="232 216 228 217 227 219 224 221 222 222 222 224 222 226 222 228 224 231
#  228 233 232 234 236 234 241 234 247 233 252 230 254 228 257 225 257 223
#  256 221 253 218 249 216 246 216 243 215 240 215 240 216 240 219 241 219
#  242 219 244 219 246 220 247 221 248 222 249 223 249 224 248 225 247 226
#  246 227 244 228 242 228 240 229 239 229 236 229 235 229 233 228 231 227
#  230 226 229 225 230 223 231 222 232 221 234 220 235 220 234 218" style="fill:darkgreen; stroke:darkgreen; stroke-width:1; fill-opacity:0.5" /><polygon points="271 205 271 204 269 204 268 205 269 206 270 206 268 207 268 207 267 207
#  266 206 266 204 267 204 268 203 269 203 270 203 272 203 272 203 273 204
#  274 205" style="fill:olive; stroke:olive; stroke-width:1; fill-opacity:0.5" /><polygon points="271 210 269 210 268 211 266 211 265 212 264 214 264 215 265 216 266 217
#  268 218 270 218 270 216 268 216 268 215 268 214 269 213 271 213 272 213
#  273 213 275 213 276 214 275 215 274 215 271 216 271 218 273 219 275 218
#  277 217 278 216 279 215 279 213 278 211 275 210 273 210" style="fill:teal; stroke:teal; stroke-width:1; fill-opacity:0.5" /><polygon points="280 233 278 233 276 233 274 234 272 236 272 237 272 239 273 241 274 242
#  276 243 280 243 280 240 278 240 277 239 277 237 278 237 279 236 284 236
#  285 237 286 238 286 239 284 240 281 240 281 243 283 243 285 243 287 242
#  289 241 290 240 291 238 290 235 287 233 284 233 281 232" style="fill:aquamarine; stroke:aquamarine; stroke-width:1; fill-opacity:0.5" /><polygon points="257 186 257 187 257 188 258 188 257 189 257 190 256 190 250 190 250 191
#  252 191 253 192 257 192 259 191 260 190 261 188 260 187 259 186 258 186" style="fill:steelblue; stroke:steelblue; stroke-width:1; fill-opacity:0.5" /><polygon points="217 157 216 157 214 158 212 159 210 160 210 161 210 162 211 164 212 164
#  214 165 216 165 217 162 215 162 215 161 216 161 218 160 220 160 222 161
#  222 161 221 162 219 162 218 162 217 165 218 165 220 165 222 164 225 164
#  226 163 227 162 228 160 226 158 224 157 221 157 219 157" style="fill:powderblue; stroke:powderblue; stroke-width:1; fill-opacity:0.5" /><polygon points="336 172 334 172 332 172 330 173 329 174 329 175 329 176 330 177 331 177
#  333 178 334 178 334 176 333 176 332 175 333 175 334 174 335 174 337 175
#  337 175 337 176 337 176 335 176 335 178 336 178 337 178 339 178 341 177
#  341 176 342 175 341 174 339 173 337 172" style="fill:dodgerblue; stroke:dodgerblue; stroke-width:1; fill-opacity:0.5" /><polygon points="332 202 331 202 329 203 325 204 325 205 324 206 324 207 324 209 325 210
#  326 211 328 212 331 212 333 213 335 213 337 213 340 212 341 211 343 210
#  343 208 342 206 341 204 340 206 338 207 338 208 338 209 337 210 335 210
#  333 210 331 209 330 209 329 208 329 207 330 206 331 205 332 205 332 205" style="fill:navy; stroke:navy; stroke-width:1; fill-opacity:0.5" /><polygon points="334 226 332 226 331 226 328 226 326 227 323 228 321 229 319 230 318 233
#  318 235 319 238 321 240 325 241 328 243 332 243 336 244 339 243 342 243
#  346 241 348 240 349 236 349 234 349 232 343 233 341 234 340 236 340 237
#  339 238 337 238 336 239 334 239 332 238 330 238 328 238 327 237 326 235
#  326 233 327 232 328 232 329 231 330 231 331 231 331 230" style="fill:magenta; stroke:magenta; stroke-width:1; fill-opacity:0.5" /><text x="201" y="185" fill="yellow">screw</text><polygon points="201 185 213 185 213 190 201 190 201 185" style="fill:blue; stroke:blue; stroke-width:1; fill-opacity:0" /><text x="206" y="188" fill="yellow">screw</text><polygon points="206 188 216 188 216 197 206 197 206 188" style="fill:purple; stroke:purple; stroke-width:1; fill-opacity:0" /><text x="228" y="207" fill="yellow">screw</text><polygon points="228 207 240 207 240 220 228 220 228 207" style="fill:red; stroke:red; stroke-width:1; fill-opacity:0" /><text x="237" y="183" fill="yellow">screw</text><polygon points="237 183 256 183 256 192 237 192 237 183" style="fill:green; stroke:green; stroke-width:1; fill-opacity:0" /><text x="232" y="175" fill="yellow">screw</text><polygon points="232 175 235 175 235 179 232 179 232 175" style="fill:orange; stroke:orange; stroke-width:1; fill-opacity:0" /><text x="266" y="200" fill="yellow">screw</text><polygon points="266 200 283 200 283 210 266 210 266 200" style="fill:salmon; stroke:salmon; stroke-width:1; fill-opacity:0" /><text x="301" y="191" fill="yellow">screw</text><polygon points="301 191 310 191 310 197 301 197 301 191" style="fill:pink; stroke:pink; stroke-width:1; fill-opacity:0" /><text x="285" y="181" fill="yellow">screw</text><polygon points="285 181 295 181 295 189 285 189 285 181" style="fill:gold; stroke:gold; stroke-width:1; fill-opacity:0" /><text x="331" y="224" fill="yellow">screw</text><polygon points="331 224 357 224 357 237 331 237 331 224" style="fill:orchid; stroke:orchid; stroke-width:1; fill-opacity:0" /><text x="332" y="190" fill="yellow">screw</text><polygon points="332 190 346 190 346 207 332 207 332 190" style="fill:slateblue; stroke:slateblue; stroke-width:1; fill-opacity:0" /><text x="352" y="182" fill="yellow">screw</text><polygon points="352 182 362 182 362 194 352 194 352 182" style="fill:limegreen; stroke:limegreen; stroke-width:1; fill-opacity:0" /><text x="379" y="197" fill="yellow">screw</text><polygon points="379 197 390 197 390 206 379 206 379 197" style="fill:seagreen; stroke:seagreen; stroke-width:1; fill-opacity:0" /><text x="221" y="215" fill="yellow">shim</

# %%
html = coco_dataset.display_image(6, use_url=False)
IPython.display.HTML(html)
# Out:
# Image:
# ======
#   height: 1080
#   width: 1920
#   id: 6
#   file_name: 600_Color_SaltAndPepper.jpg
#   segmentations (21):
#     140:blue:{'supercategory': 'screw', 'id': 0, 'name': 'screw'}
#     141:purple:{'supercategory': 'screw', 'id': 0, 'name': 'screw'}
#     142:red:{'supercategory': 'screw', 'id': 0, 'name': 'screw'}
#     143:green:{'supercategory': 'screw', 'id': 0, 'name': 'screw'}
#     144:orange:{'supercategory': 'screw', 'id': 0, 'name': 'screw'}
#     145:salmon:{'supercategory': 'screw', 'id': 0, 'name': 'screw'}
#     146:pink:{'supercategory': 'screw', 'id': 0, 'name': 'screw'}
#     147:gold:{'supercategory': 'screw', 'id': 0, 'name': 'screw'}
#     148:orchid:{'supercategory': 'screw', 'id': 0, 'name': 'screw'}
#     149:slateblue:{'supercategory': 'screw', 'id': 0, 'name': 'screw'}
#     150:limegreen:{'supercategory': 'screw', 'id': 0, 'name': 'screw'}
#     151:seagreen:{'supercategory': 'shim', 'id': 1, 'name': 'shim'}
#     152:darkgreen:{'supercategory': 'shim', 'id': 1, 'name': 'shim'}
#     153:olive:{'supercategory': 'shim', 'id': 1, 'name': 'shim'}
#     154:teal:{'supercategory': 'shim', 'id': 1, 'name': 'shim'}
#     155:aquamarine:{'supercategory': 'shim', 'id': 1, 'name': 'shim'}
#     156:steelblue:{'supercategory': 'shim', 'id': 1, 'name': 'shim'}
#     157:powderblue:{'supercategory': 'shim', 'id': 1, 'name': 'shim'}
#     158:dodgerblue:{'supercategory': 'shim', 'id': 1, 'name': 'shim'}
#     159:navy:{'supercategory': 'shim', 'id': 1, 'name': 'shim'}
#     160:magenta:{'supercategory': 'shim', 'id': 1, 'name': 'shim'}
# <div class="container" style="position:relative;"><img src="train2019/600_Color_SaltAndPepper.jpg" style="position:relative;top:0px;left:0px;width:600px;"><div class="svgclass"><svg width="600" height="337.5"><polygon points="208 157 207 161 210 164 211 164 217 168 218 164 220 163 215 160 216 159
#  213 155 209 157" style="fill:blue; stroke:blue; stroke-width:1; fill-opacity:0.5" /><polygon points="220 163 219 164 217 168 219 170 220 170 225 175 229 175 229 172 225 168
#  225 166 223 163" style="fill:purple; stroke:purple; stroke-width:1; fill-opacity:0.5" /><polygon points="202 164 202 166 207 168 208 169 209 169 211 169 211 167 210 166 209 166
#  208 166 203 164" style="fill:red; stroke:red; stroke-width:1; fill-opacity:0.5" /><polygon points="224 176 223 177 224 179 226 180 227 181 232 184 233 184 233 182 228 178
#  228 176 225 175 224 176" style="fill:green; stroke:green; stroke-width:1; fill-opacity:0.5" /><polygon points="267 157 267 158 267 159 273 161 274 161 275 162 277 162 277 160 277 158
#  275 157 274 158" style="fill:orange; stroke:orange; stroke-width:1; fill-opacity:0.5" /><polygon points="272 186 271 187 271 190 283 190 284 192 288 193 288 192 289 189 289 186
#  288 184 285 184 283 186" style="fill:salmon; stroke:salmon; stroke-width:1; fill-opacity:0.5" /><polygon points="269 222 269 225 256 227 257 233 270 231 270 233 274 233 275 229 274 225
#  273 222 270 222" style="fill:pink; stroke:pink; stroke-width:1; fill-opacity:0.5" /><polygon points="302 179 302 182 301 184 301 185 303 188 303 189 308 189 310 185 308 181
#  307 181 307 178 305 177 303 177" style="fill:gold; stroke:gold; stroke-width:1; fill-opacity:0.5" /><polygon points="323 215 322 215 321 216 322 218 330 223 331 224 334 224 335 224 336 222
#  335 219 333 218 332 219" style="fill:orchid; stroke:orchid; stroke-width:1; fill-opacity:0.5" /><polygon points="348 195 349 197 349 197 351 198 352 198 354 197 352 195 351 195 351 193
#  350 193" style="fill:slateblue; stroke:slateblue; stroke-width:1; fill-opacity:0.5" /><polygon points="332 162 332 165 339 162 340 162 340 159 338 158 337 159 337 160 335 160
#  334 161" style="fill:limegreen; stroke:limegreen; stroke-width:1; fill-opacity:0.5" /><polygon points="229 182 226 182 224 181 220 182 216 183 213 184 212 186 212 189 217 192
#  221 192 226 191 229 190 233 186 232 184 230 183 226 185 227 186 226 187
#  222 188 219 187 218 186 219 185 222 185 226 185 226 185" style="fill:seagreen; stroke:seagreen; stroke-width:1; fill-opacity:0.5" /><polygon points="202 195 202 196 203 197 205 197 207 198 209 197 210 195 209 194 208 194
#  206 193 204 193 203 194 204 195 206 195 207 195 208 195 207 196 205 196
#  204 196 204 195" style="fill:darkgreen; stroke:darkgreen; stroke-width:1; fill-opacity:0.5" /><polygon points="273 223 275 222 277 221 280 221 283 221 286 222 287 224 287 226 287 228
#  284 229 281 230 278 230 275 229 274 227 276 226 277 227 281 227 284 226
#  284 225 281 224 278 224 276 225 276 226 274 226 274 225" style="fill:olive; stroke:olive; stroke-width:1; fill-opacity:0.5" /><polygon points="327 200 327 202 328 203 331 205 334 205 338 205 342 204 343 202 343 200
#  341 199 339 197 334 197 330 197 328 198 327 199 332 200 334 199 336 199
#  338 200 339 201 339 202 336 202 334 202 332 202 331 201 332 200 327 200" style="fill:teal; stroke:teal; stroke-width:1; fill-opacity:0.5" /><polygon points="343 184 343 186 343 187 346 188 349 189 352 189 354 189 356 187 357 186
#  356 184 351 182 348 182 345 183 344 184 347 185 349 185 352 185 353 186
#  353 186 351 187 349 187 347 186 346 185 347 185" style="fill:aquamarine; stroke:aquamarine; stroke-width:1; fill-opacity:0.5" /><polygon points="372 191 373 193 374 193 376 193 377 192 377 191 374 191 373 191 374 192
#  375 192 376 192 375 193 374 192 374 192" style="fill:steelblue; stroke:steelblue; stroke-width:1; fill-opacity:0.5" /><polygon points="369 207 369 208 370 209 373 209 374 209 374 207 372 206 370 207 371 207
#  373 208 373 208 371 208 371 207" style="fill:powderblue; stroke:powderblue; stroke-width:1; fill-opacity:0.5" /><polygon points="340 159 341 159 344 160 346 161 345 162 345 163 343 164 340 164 338 164
#  337 163 339 162 340 163 342 163 343 162 343 161 341 161 340 161" style="fill:dodgerblue; stroke:dodgerblue; stroke-width:1; fill-opacity:0.5" /><polygon points="283 192 282 193 282 195 283 197 286 199 291 200 298 198 300 195 300 193
#  296 191 293 190 290 190 289 190 288 193 291 193 294 193 296 195 296 195
#  294 196 291 196 288 196 286 195 287 193" style="fill:navy; stroke:navy; stroke-width:1; fill-opacity:0.5" /><polygon points="252 184 252 186 255 188 258 189 265 189 269 188 270 188 272 186 274 186
#  274 183 273 180 268 179 265 179 259 179 255 180 253 182 252 183 258 183
#  260 182 262 182 265 182 267 182 268 183 269 184 268 185 266 186 263 186
#  260 186 258 185 257 184" style="fill:magenta; stroke:magenta; stroke-width:1; fill-opacity:0.5" /><text x="207" y="155" fill="yellow">screw</text><polygon points="207 155 220 155 220 168 207 168 207 155" style="fill:blue; stroke:blue; stroke-width:1; fill-opacity:0" /><text x="217" y="162" fill="yellow">screw</text><polygon points="217 162 229 162 229 175 217 175 217 162" style="fill:purple; stroke:purple; stroke-width:1; fill-opacity:0" /><text x="202" y="164" fill="yellow">screw</text><polygon points="202 164 211 164 211 169 202 169 202 164" style="fill:red; stroke:red; stroke-width:1; fill-opacity:0" /><text x="223" y="175" fill="yellow">screw</text><polygon points="223 175 233 175 233 184 223 184 223 175" style="fill:green; stroke:green; stroke-width:1; fill-opacity:0" /><text x="267" y="157" fill="yellow">screw</text><polygon points="267 157 277 157 277 162 267 162 267 157" style="fill:orange; stroke:orange; stroke-width:1; fill-opacity:0" /><text x="270" y="184" fill="yellow">screw</text><polygon points="270 184 289 184 289 193 270 193 270 184" style="fill:salmon; stroke:salmon; stroke-width:1; fill-opacity:0" /><text x="256" y="221" fill="yellow">screw</text><polygon points="256 221 275 221 275 233 256 233 256 221" style="fill:pink; stroke:pink; stroke-width:1; fill-opacity:0" /><text x="301" y="177" fill="yellow">screw</text><polygon points="301 177 310 177 310 189 301 189 301 177" style="fill:gold; stroke:gold; stroke-width:1; fill-opacity:0" /><text x="321" y="215" fill="yellow">screw</text><polygon points="321 215 336 215 336 224 321 224 321 215" style="fill:orchid; stroke:orchid; stroke-width:1; fill-opacity:0" /><text x="348" y="193" fill="yellow">screw</text><polygon points="348 193 354 193 354 198 348 198 348 193" style="fill:slateblue; stroke:slateblue; stroke-width:1; fill-opacity:0" /><text x="331" y="158" fill="yellow">screw</text><polygon points="331 158 340 158 340 165 331 165 331 158" style="fill:limegreen; stroke:limegreen; stroke-width:1; fill-opacity:0" /><text x="212" y="181" fill="yellow">shim</text><polygon points="212 181 232 181 232 191 212 191 212 181" style="fill:seagreen; stroke:seagreen; stroke-width:1; fill-opacity:0" /><text x="202" y="193" fill="yellow">shim</text><polygon points="202 193 210 193 210 197 202 197 202 193" style="fill:darkgreen; stroke:darkgreen; stroke-width:1; fill-opacity:0" /><text x="273" y="220" fill="yellow">shim</text><polygon points="273 220 287 220 287 230 273 230 273 220" style="fill:olive; stroke:olive; stroke-width:1; fill-opacity:0" /><text x="327" y="196" fill="yellow">shim</text><polygon points="327 196 343 196 343 205 327 205 327 196" style="fill:teal; stroke:teal; stroke-width:1; fill-opacity:0" /><text x="343" y="182" fill="yellow">shim</text><polygon points="343 182 356 182 356 189 343 189 343 182" style="fill:aquamarine; stroke:aquamarine; stroke-width:1; fill-opacity:0" /><text x="372" y="190" fill="yellow">shim</text><polygon points="372 190 377 190 377 193 372 193 372 190" style="fill:steelblue; stroke:steelblue; stroke-width:1; fill-opacity:0" /><text x="369" y="206" fill="yellow">shim</text><polygon points="369 206 374 206 374 209 369 209 369 206" style="fill:powderblue; stroke:powderblue; stroke
